# %%
from pyspark import SparkConf, SparkContext

# %%
conf = SparkConf().setAppName('midterm1')
sc.stop()
sc = SparkContext(conf=conf)

# %%
sc
# Out:
# <SparkContext master=local[*] appName=midterm1>

# %% [markdown]
# ---

# %%
data3 = sc.textFile(
    'Encrypted-3.txt'
)

# %%
data3.collect()
# Out:
# ['',
#  '                              OTWIFS (T.X.)',
#  "                    N ITS'Y PSTB. XMJ BTZQIS'Y YJQQ RJ.",
#  '                         ',
#  '          GZY GJKTWJ YMJ QJYYJW INXFUUJFWX HTRUQJYJQD BJ WJFI TSJ RTWJ',
#  '          QNSJ: "YMJ YWZYM NX..."',
#  '                         ',
#  '                                                                         INXXTQAJ YT:',
#  '                         ',
#  '                         ',
#  '          JCY. QTZNXANQQJ HMZWHM - KWTSY XYJUX - QFYJ FKYJWSTTS',
#  '                         ',
#  '          IFNXD FSI YTR, SJBQD RFWWNJI, UTXJ KTW UMTYTX.',
#  '                         ',
#  '                              OTWIFS (T.X.)',
#  "                    FSDBFDX, YMFY IFD, FY KNAJ T'HQTHP,",
#  '                    IFNXD KFDJ RFWWNJI YTR GZHMFSFS',
#  '                    BNYM RTWJ UTRU FSI HNWHZRXYFSHJ',
#  '                    YMFS QTZNXANQQJ MFI JAJW XJJS...',
#  '                         ',
#  '                                                                         INXXTQAJ YT:',
#  '                         ',
#  '                         ',
#  '          JCY. YNRJX XVZFWJ - SNLMY',
#  '                         ',
#  '          OTWIFS FSI SNHP XYWTQQ GJSJFYM YMJ XTFWNSL JQJHYWNH XNLSX.',
#  '                         ',
#  '                                             OTWIFS',
#  '                    FKYJW YMJ MTSJDRTTS, N XFB YMJR NS',
#  '                    XFSYF GFWGFWF. NY BFX YTZHMNSL,',
#  '                    FHYZFQQD...',
#  '                                             (RTWJ)',
#  '                                                                  54.',
#  '                         ',
#  "                                             OTWIFS (HTSY'I)",
#  "                    N'I SJAJW XJJS F LNWQ XT NS QTAJ",
#  '                    BNYM MJW MZXGFSI.',
#  '                                       (RZXJX HDSNHFQQD)',
#  '                    F BJJP QFYJW, YTR HWFXMJI MNX HFW.',
#  '                    YMJ LNWQ BNYM MNR BFX F HMFRGJWRFNI',
#  '                    FY YMJ XFSYF GFWGFWF MTYJQ. NY LTY',
#  '                    NSYT FQQ YMJ UFUJWX...',
#  '                         ',
#  '          FX OTWIFS FSI SNHP FUUWTFHM YMJ HZWG, BFNYNSL KTW F HFG, SNHP',
#  "          YZWSX YT OTWIFS; MJ'X XYWZHP GD F... XZIIJS, UZEEQJI YMTZLMY.",
#  '                         ',
#  '                                             SNHP',
#  "                    NY'X F XYWFSLJ HTNSHNIJSHJ, NXS'Y",
#  "                    NY? LFYXGD'X MTZXJ GJNSL OZXY",
#  '                    FHWTXX YMJ GFD...',
#  '                         ',
#  '          OTWIFS BMNWQX WTZSI--',
#  '                         ',
#  '                                             OTWIFS',
#  "                    NY'X ST HTNSHNIJSHJ. MJ GTZLMY YMFY",
#  '                    MTZXJ YT GJ SJFW MJW, MJ YMWJB FQQ',
#  "                    YMTXJ UFWYNJX MTUNSL XMJ'I BFSIJW",
#  '                    NS TSJ SNLMY. MJ HTSXYFSYQD FXPJI',
#  '                    FGTZY IFNXD... N BFX YMJ KNWXY TSJ',
#  '                    BMT PSJB MJW.',
#  '                         ',
#  '          SNHP YFPJX YMNX NS; FX NK XJJNSL LFYXGD KTW YMJ KNWXY YNRJ.',
#  '                         ',
#  '                                             SNHP',
#  "                    FQQ YMFY KTW F LNWQ MJ MFXS'Y XJJS",
#  '                    NS KNAJ DJFWX...? FSI STB MJ OZXY',
#  '                    BFSYX RJ YT MFAJ MJW KTW YJF...?',
#  '                                       (YT MNRXJQK)',
#  '                    YMJ RTIJXYD TK NY.',
#  '                         ',
#  '                                             OTWIFS',
#  '                    PNSI TK YFPJX DTZW GWJFYM FBFD,',
#  "                    ITJXS'Y NY?",
#  '                         ',
#  '          F HFG UZQQX ZU, FSI SNHP TUJSX YMJ ITTW...',
#  '                         ',
#  '                         ',
#  '          NSY. YFCN - HTSYNSZTZX',
#  '                         ',
#  '          OTWIFS XQNIJX NS...',
#  '                         ',
#  '                                             YFCN IWNAJW',
#  '                    JAJSNSL XBJJYMJFWYX! BMJWJ YT?',
#  '                         ',
#  '                                             OTWIFS',
#  '                    QTSL NXQFSI, UQJFXJ.',
#  '                                                                    55.',
#  '                         ',
#  '                         ',
#  '                                             SNHP',
#  '                    FSI DTZ YMNSP N XMTZQI? N RJFS,',
#  '                    ITJX IFNXD BFSY YT XJJ LFYXGD?',
#  '                         ',
#  '                                             OTWIFS',
#  '                        (F XYJWS BMNXUJW)',
#  "                    XMJ'X FGXTQZYJQD STY YT PSTB. DTZ",
#  '                    FWJ OZXY XZUUTXJI YT NSANYJ MJW',
#  '                    TAJW XT MJ HFS "MFUUJS YT IWTU GD."',
#  '                         ',
#  '          HQTXJ TS: SNHP, ZSXZWJ...',
#  '                         ',
#  '                              SNHP (A.T.)',
#  '                    N WJRJRGJW KJJQNSL YTWS. BFX NY',
#  '                    WNLMY YT GWNSL RD HTZXNS IFNXD, F',
#  '                    RFWWNJI BTRFS, YTLJYMJW BNYM F RFS',
#  '                    N MFWIQD PSJB?',
#  '                         ',
#  '          FX SNHP BTSIJWX, YMJ YFCN KQTFYX FHWTXX YNRJX XVZFWJ, ZSIJW',
#  '          YMJ HTTQ JDJX TK YMJ RFS NS YMJ FWWTB XMNWY...',
#  '                         ',
#  '                                                                         INXXTQAJ YT:',
#  '                         ',
#  '                         ',
#  "          JCY. INWY YWFHP YT SNHP'X GZSLFQTB - SNLMY",
#  '                         ',
#  "          SNHP'X YFCN UZQQX UFXY LFYXGD'X RFSXNTS, FGQFEJ BNYM QNLMY.",
#  '                         ',
#  '                              SNHP (A.T.)',
#  "                    BMJS N WJYZWSJI MTRJ, LFYXGD'X BFX",
#  '                    QNY, KWTR YTBJW YT HJQQFW, FX NK',
#  '                    KTW FSTYMJW BNQI UFWYD. GZY...',
#  "                    YMJWJ BFXS'Y F XTZSI.",
#  '                         ',
#  '                         ',
#  "          JCY. SNHP'X GZSLFQTB - SNLMY",
#  '                         ',
#  "          FX SNHP'X YFCN LWTFSX FBFD, LFYXGD FUUJFWX XYWNINSL YMWTZLM",
#  '          YMJ NQQZRNSFYJI YWJJX YTBFWI SNHP.',
#  '                         ',
#  '                                             SNHP',
#  "                    DTZW UQFHJ QTTPX QNPJ YMJ BTWQI'X",
#  '                    KFNW... TW HTSJD NXQFSI!',
#  '                         ',
#  '                                             LFYXGD',
#  '                                       (YJWWNGQD FSCNTZX)',
#  "                    FM, ITJX NY? N'AJ... N'AJ OZXY GJJS",
#  "                    LQFSHNSL NSYT XTRJ WTTRX... QJY'X",
#  '                    LT YT HTSJD NXQFSI, TQI XUTWY, BJ',
#  '                    HFS YFPJ RD HFW--',
#  '                         ',
#  '                                             SNHP',
#  "                    NY'X YTT QFYJ YTSNLMY.",
#  '                                                                  56.',
#  '                         ',
#  '                         ',
#  '                                             LFYXGD',
#  '                    TW BJ HFS YFPJ F UQZSLJ NS YMJ',
#  "                    XBNRRNSL UTTQ? N MFAJS'Y RFIJ ZXJ",
#  '                    TK NY FQQ XZRRJW...',
#  '                         ',
#  '                                             SNHP',
#  '                    N RZXY LT YT GJI...',
#  '                         ',
#  '          LFYXGD QTTPX HWJXYKFQQJS. SNHP UZYX MNR TZY TK MNX RNXJWD.',
#  '                         ',
#  "                                             SNHP (HTSY'I)",
#  "                    MFUUD YT IT NY. OFD-- N'R LTNSL YT",
#  '                    HFQQ IFNXD FSI NSANYJ MJW YT YJF.',
#  '                         ',
#  '                                             LFYXGD',
#  "                    TM, YMFY'X FQWNLMY. N ITS'Y BFSY YT",
#  '                    UZY DTZ YT FSD YWTZGQJ...',
#  '                         ',
#  '                                             SNHP',
#  '                    BMFY IFD BTZQI XZNY DTZ?',
#  '                         ',
#  '                                             LFYXGD',
#  "                    BMFY IFD BTZQI XZNY DTZ...? N ITS'Y",
#  '                    BFSY YT UZY DTZ YT FSD YWTZGQJ...',
#  '                         ',
#  '                                             SNHP',
#  '                    IFD FKYJW YTRTWWTB FQWNLMY?',
#  '                         ',
#  '                                             LFYXGD',
#  "                    IFD FKYJW YTRTWWTB? BJQQ, N'I...",
#  "                    N'I BFSY YT LJY YMJ LWFXX HZY.",
#  '                         ',
#  '          YMJD GTYM QTTP FY YMJ LWFXX - YMJWJ NX F XMFWU QNSJ BMJWJ',
#  "          SNHP'X WFLLJI QFBS JSIX FSI LFYXGD'X RFSNHZWJI TSJ GJLNSX.",
#  '                         ',
#  "                                             LFYXGD (HTSY'I)",
#  "                    YMJWJ'X FSTYMJW QNYYQJ YMNSL... N",
#  '                    YMTZLMY-- QTTP MJWJ, TQI XUTWY--',
#  "                    DTZ ITS'Y RFPJ RZHM RTSJD, IT DTZ?",
#  '                         ',
#  '                                             SNHP',
#  '                    STY WJFQQD.',
#  '                         ',
#  '                                              LFYXGD',
#  "                    NK DTZ'QQ UFWITS RD... DTZ XJJ, N",
#  '                    HFWWD TS F QNYYQJ GZXNSJXX TS YMJ',
#  '                    XNIJ - F XTWY TK XNIJQNSJ - DTZ',
#  "                    ZSIJWXYFSI BMFY N'R XFDNSL WNLMY?",
#  "                    DTZ'WJ XJQQNSL GTSIX, FWJS'Y DTZ,",
#  '                    TQI XUTWY?',
#  '                         ',
#  '                                                SNHP',
#  '                    YWDNSL YT.',
#  '                                                                    57.',
#  '                         ',
#  '                         ',
#  '                                             LFYXGD',
#  '                    BJQQ, YMNX RNLMY NSYJWJXY DTZ... NY',
#  '                    MFUUJSX YT GJ F WFYMJW HTSKNIJSYNFQ',
#  '                    XTWY TK YMNSL... GZY DTZ RNLMY UNHP',
#  '                    ZU F SNHJ GNY TK RTSJD.',
#  '                         ',
#  '                                             SNHP',
#  "                    N'AJ LTY RD MFSIX KZQQ.",
#  '                         ',
#  "          LFYXGD'X KFHJ KFQQX.",
#  '                         ',
#  '                                             LFYXGD',
#  "                    DTZ BTZQIS'Y MFAJ YT IT FSD",
#  '                    GZXNSJXX BNYM BTQKXMJNR. N FXXZWJ',
#  '                    DTZ.',
#  '                         ',
#  '                                             SNHP',
#  '                    ST, ST, ST... NYX F KFATW OFD. OZXY',
#  '                    F KFATW.',
#  '                         ',
#  "          SNHP'X XNSHJWNYD INXFWRX LFYXGD; F YNSD, JRGFWWFXXJI STI.",
#  '                         ',
#  "                                             SNHP (HTSY'I)",
#  '                    MFUUD YT IT NY.',
#  '                         ',
#  '                                                LFYXGD',
#  '                    F KFATW?',
#  '                         ',
#  '                                                SNHP',
#  '                    DJX.',
#  '                         ',
#  '          FX NK ST TSJ MFX JAJW ITSJ MNR F KFATW GJKTWJ NS MNX QNKJ...',
#  '                         ',
#  '                                             LFYXGD',
#  '                    FM, WNLMY, WNLMY... LTTISNLMY.',
#  '                         ',
#  '                                                SNHP',
#  '                    LTTISNLMY.',
#  '                         ',
#  '          BNYM YMNX, LFYXGD YZWSX FSI XYWTQQX GFHP YTBFWI MNX GQFENSL',
#  "          HFXYQJ. SNHP'X LFEJ KFQQX ZUTS YMJ ZSPJRUY QFBS. MJ XRNQJX.",
#  '                         ',
#  '                                                                         INXXTQAJ YT:',
#  '                         ',
#  '                         ',
#  "          JCY. SNHP'X GZSLFQTB - KWTSY QFBS - IFD",
#  '                         ',
#  '          YTU XMTY: FS JSTWRTZX RTBJW HQFYYJWX YMWTZLM KWFRJ, HFWANSL',
#  "          SNHP'X ZSPJRUY QFBS NSYT F KWJXM, GWTFI, GFSI TK LWJJS.",
#  '                         ',
#  "          WJAJFQ: FS FWRD TK LFWISIJWX LNANSL SNHP'X QFBS FSI LFWIJS F",
#  '          RFPJ-TAJW, KWJXM UFNSY, SJB KQTBJWX, YWNRRJI MJILJX...',
#  '                         ',
#  '                                                                         INXXTQAJ YT:',
#  '                                                                    58.',
#  '                         ',
#  '                         ',
#  "          JCY. SNHP'X GZSLFQTB - KWTSY QFBS - YMJ KTQQTBNSL IFD",
#  '                         ',
#  '          MJFAD WFNS STB KFQQX.',
#  '                         ',
#  '          LFYXGD, IWJXXJI NS BMNYJ KQFSSJQ XZNY, XNQAJW XMNWY, FSI LTQI',
#  '          YNJ, QJFIX F ITEJS ZRGWJQQF-MTQINSL XJWAFSYX FHWTXX YMJ QFBS.',
#  '          MJWETL MTQIX FS ZRGWJQQF TAJW LFYXGD; YMJ TYMJW XJWAFSYX',
#  '          XMJQYJW JCYWFAFLFSY KQTWFQ FWWFSLJRJSYX NS HWDXYFQ AFXJX...',
#  '                         ',
#  '          SNHP BFYHMJX YMJ UFWFIJ YMWTZLM MNX BNSITB, TUJSNSL MNX ITTW',
#  '          OZXY FX LFYXGD FWWNAJX; YMJ XJWAFSYX HTSYNSZJ NSXNIJ.',
#  '                         ',
#  '          TS YMJ UTWHM, LFYXGD QTTPX FWTZSI INXYWFHYJIQD.',
#  '                         ',
#  '                                             LFYXGD',
#  '                    TSJ TK YMJ UFUJWX XFNI YMJD YMTZLMY',
#  '                    YMJ WFNS BTZQI XYTU FGTZY KTZW. N',
#  '                    YMNSP NY BFX YMJ OTZWSFQ...',
#  '                         ',
#  '          FS FBPBFWI GJFY.',
#  '                         ',
#  '                                             SNHP',
#  '                    YMJ LWFXX QTTPX KNSJ.',
#  '                         ',
#  '                                             LFYXGD',
#  '                    LWFXX?',
#  '                         ',
#  '          LFYXGD QTTPX FY SNHP BNYMTZY WJFQQD HTRUWJMJSINSL, TW XJJNSL.',
#  '                         ',
#  "                                             LFYXGD (HTSY'I)",
#  '                    BMFY LWFXX?',
#  '                         ',
#  '                                                        XZIIJS HZY YT:',
#  '                         ',
#  '                         ',
#  "          NSY. SNHP'X GZSLFQTB - QNANSL WTTR - IFD",
#  '                         ',
#  '          YNLMY TS: F RFSYJQUNJHJ HQTHP, YNHPNSL NS YMJ YJSXJ XNQJSHJ.',
#  '                         ',
#  '          BNIJW: YMJ WTTR NX HWTBIJI BNYM FGXZWIQD JCYWFAFLFSY KQTWFQ',
#  '          FWWFSLJRJSYX. SNHP XNYX BFYHMNSL FX LFYXGD NSYJSXJQD UFHJX.',
#  '          YMJ XNQJSHJ XYWJYHMJX, FSI XYWJYHMJX... KNSFQQD...',
#  '                         ',
#  '                                             LFYXGD',
#  '                    MFAJ DTZ LTY JAJWDYMNSL DTZ SJJI?',
#  '                         ',
#  '                                             SNHP',
#  '                    UJWMFUX RTWJ KQTBJWX?',
#  '                         ',
#  '                                             LFYXGD',
#  "                    N YMNSP YMJD INI F KNSJ OTG, ITS'Y",
#  '                    DTZ?',
#  '                                                                  59.',
#  '                         ',
#  '                         ',
#  '                                                SNHP',
#  '                    GJFZYNKZQ.',
#  '                         ',
#  '                                             LFYXGD',
#  "                    DTZ YMNSP NY'X YTT RZHM?",
#  '                         ',
#  '                                             SNHP',
#  "                    N YMNSP NY'X BMFY DTZ BFSY.",
#  '                         ',
#  '                                             LFYXGD',
#  "                    N YMNSP XT YTT... XMJ'QQ GJ",
#  "                    NRUWJXXJI, BTS'Y XMJ TQI XUTWY?",
#  '                         ',
#  '                                                SNHP',
#  '                    N FR.',
#  '                         ',
#  '          BNYM YMNX, LFYXGD XYWFNLMYJSX MNX XZNY, XNYX, FSI MZWWNJIQD',
#  '          HMJHPX MNX BFYHM. FSTYMJW QTSL XNQJSHJ...',
#  '                         ',
#  '          UZXM NS TS: LFYXGD... XZIIJSQD! MJ QJFUX YT MNX KJJY!',
#  '                         ',
#  '                                             LFYXGD',
#  "                    N HFS'Y BFNY FQQ IFD. N'R QJFANSL!",
#  '                         ',
#  '                                             SNHP',
#  "                    ITS'Y GJ XNQQD. NY'X OZXY YBT",
#  '                    RNSZYJX YT KTZW...',
#  '                         ',
#  '          GZY LFYXGD MJFIX KTW YMJ ITTW...',
#  '                         ',
#  '                                             LFYXGD',
#  "                    STGTID'X HTRNSL YT YJF. NY'X YTT",
#  '                    QFYJ!',
#  '                         ',
#  "          GJJJJJU! LFYXGD LQNRUXJX IFNXD'X WTQQX WTDHJ FWWNANSL TZY",
#  '          KWTSY, FSI YZWSX YT SNHP, KQZXMJI BNYM KWJXM UFSNH.',
#  '                         ',
#  '                                                SNHP',
#  "                    NY'X MJW.",
#  '                         ',
#  '          UZXM NS TS LFYXGD: RNSI WFHNSL...',
#  '                         ',
#  '                         ',
#  "          JCY. SNHP'X GZSLFQTB - IFD",
#  '                         ',
#  "          IFNXD'X HMFZKKJZW-IWNAJS WTQQX UZQQX ZU NS YMJ RZIID IWNAJ.",
#  '                         ',
#  '          FX SNHP FXXNXYX IFNXD KWTR YMJ HFW...',
#  '                         ',
#  '                                             IFNXD',
#  '                    NX YMNX FGXTQZYJQD BMJWJ DTZ QNAJ,',
#  '                    RD IJFWJXY TSJ?',
#  '                         ',
#  '          XMJ QTTPX FY MNR BNYM F RDXYJWNTZX XRNQJ.',
#  '                                                                  60.',
#  '                         ',
#  '                         ',
#  "                                             IFNXD (HTSY'I)",
#  '                    BMD INI N MFAJ YT HTRJ FQTSJ? FWJ',
#  '                    DTZ NS QTAJ BNYM RJ?',
#  '                         ',
#  '                                             SNHP',
#  "                    YMFY'X YMJ XJHWJY TK HFWWFBFD",
#  '                    HFXYQJ.',
#  '                                       (UQFDNSL FQTSL)',
#  '                    YJQQ DTZW HMFZKKJZW YT LT KFW FBFD.',
#  '                         ',
#  '                                             IFNXD',
#  '                    HTRJ GFHP NS FS MTZW, KJWINJ!',
#  '                                       (LWFAJ RZWRZW)',
#  '                    MNX SFRJ NX KJWINJ.',
#  '                         ',
#  '                         ',
#  "          NSY. SNHP'X GZSLFQTB - MFQQ - IFD",
#  '                         ',
#  '          IFNXD HTSYNSZJX FMJFI NSYT YMJ QNANSL WTTR.',
#  '                         ',
#  "          SNHP MFSLX GFHP FSI QNXYJSX MTUJKZQQD YT IFNXD'X WJFHYNTS FY",
#  '          INXHTAJWNSL LFYXGD. MJ XRNQJX FX MJ MJFWX F IJQNLMYJI...',
#  '                         ',
#  '                              IFNXD (T.X.)',
#  "                    TM--! TM, RD LTTISJXX. N... N HFS'Y",
#  '                    GJQNJAJ NY. DTZ-- INI DTZ WFSXFHP F',
#  '                    LWJJSMTZXJ?',
#  '                         ',
#  '                         ',
#  "          NSY. SNHP'X GZSLFQTB - QNANSL WTTR - HTSYNSZTZX",
#  '                         ',
#  '                                             IFNXD',
#  '                                       (YT MJWXJQK)',
#  '                    MJ NX NS QTAJ BNYM RJ...',
#  '                         ',
#  '          SNHP JSYJWX, GZY NX XMTHPJI YT INXHTAJW YMFY LFYXGD NX STY',
#  "          YMJWJ. IFNXD'X RJWJQD GJJS FIRNWNSL YMJ KQTBJW INXUQFD...",
#  '                         ',
#  '                                             SNHP',
#  "                    YMFY'X KZSSD.",
#  '                         ',
#  '                                             IFNXD',
#  "                    BMFY'X KZSSD?",
#  '                         ',
#  '          PSTHP. PSTHP. XTRJTSJ NX FY YMJ ITTW.',
#  '                         ',
#  '                                             SNHP',
#  '                    TSJ RTRJSY...',
#  '                         ',
#  '                         ',
#  "          NSY. SNHP'X GZSLFQTB - MFQQ - HTSYNSZTZX",
#  '                         ',
#  '          SNHP TUJSX YMJ ITTW.',
#  '                                                                    61.',
#  '                         ',
#  '                         ',
#  '          LFYXGD, UFQJ FX IJFYM FSI XTFPJI, LQFWJX RNXJWFGQD FY SNHP.',
#  '                         ',
#  '                                             SNHP',
#  '                    BMFY FWJ DTZ ITNSL?',
#  '                         ',
#  '          BNYMTZY F BTWI, LFYXGD XYFQPX UFXY MNR, NSYT...',
#  '                         ',
#  '                         ',
#  "          NSY. SNHP'X GZSLFQTB - QNANSL WTTR - HTSYNSZTZX",
#  '                         ',
#  '          IFNXD, MJW GFHP YT YMJ ITTW, NX XYNQQ RFWAJQQNSL FY YMJ',
#  '          KQTBJWX. YMJS XMJ YZWSX. XJJX LFYXGD. F XMFWU NSYFPJ TK',
#  '          GWJFYM...',
#  '                         ',
#  '          YMJ WJZSNYJI QTAJWX XYFSI, XYFWNSL FY JFHM TYMJW KTW F QTSL,',
#  "          XZWWJFQ, RTRJSY TK INXGJQNJK. LFYXGD, JDJX QTHPJI YT IFNXD'X,",
#  '          NX IWTBSNSL NS JRTYNTS. IFNXD KNSFQQD RFSFLJX FS FWYNKNHNFQ,',
#  '          HMTPNSL RZWRZW.',
#  '                         ',
#  '                                             IFNXD',
#  "                    N'R HJWYFNSQD LQFI YT XJJ DTZ",
#  '                    FLFNS.',
#  '                         ',
#  "          LFYXGD'X KFHJ NX KQZXMJI; YMJ AJNSX XYFSI TZY TS MNX SJHP FX",
#  '          MNX QNUX XUFXR NS F MTUJQJXX FYYJRUY YT XUJFP.',
#  '                         ',
#  '          KNSFQQD, MJ KNSIX BTWIX...',
#  '                         ',
#  '                                             LFYXGD',
#  "                    N'R... HJWYFNSQD LQFI YT XJJ DTZ FX",
#  '                    BJQQ.',
#  '                         ',
#  '          YMJNW MJFWYX UTZSI - YMJ YJSXNTS JCHWZHNFYNSL.',
#  '                         ',
#  '          JJJJPPP! YMJ XHWJFR TK F GTNQNSL PJYYQJ TKK XHWJJS GWJFPX YMJ',
#  '                         YJSXNTS--',
#  '                         ',
#  '                                                                           HZY YT:',
#  '                         ',
#  '                         ',
#  "          NSY. SNHP'X GZSLFQTB - QNANSL WTTR - IFD",
#  '                         ',
#  '          LFYXGD WJHQNSJX ZSHTRKTWYFGQD FLFNSXY YMJ RFSYJQUNJHJ. MNX',
#  '          JQGTB WJXYX SJFW YMJ RFSYJQUNJHJ HQTHP. IFNXD XNYX TUUTXNYJ;',
#  '          KWTEJS TS YMJ JILJ TK F HMFNW.',
#  '                         ',
#  '          YMJ WFYYQJ TK YMJ YJF YWFD FX SNHP JSYJWX TSQD HTSYWNGZYJX YT',
#  '          YMJ FQWJFID ZSGJFWFGQJ YJSXNTS. LFYXGD RFSFLJX YT RZWRZW.',
#  '                         ',
#  '                                             LFYXGD',
#  "                    BJ'AJ RJY GJKTWJ...",
#  '                         ',
#  "          XZIIJSQD YMJ HQTHP YNQYX FY YMJ UWJXXZWJ TK LFYXGD'X JQGTB...",
#  '                                                                     62.',
#  '                         ',
#  '                         ',
#  '          FSI KFQQX! FSI GWJFPX!',
#  '                         ',
#  "                                             LFYXGD (HTSY'I)",
#  '                    FM... XTWWD...',
#  '                         ',
#  '          MJ HQZRXNQD YWNJX YT WJUFNW YMJ HQTHP; GZY IWTUX NY FLFNS!',
#  '                         ',
#  '                                             SNHP',
#  '                                       (NINTYNHFQQD)',
#  "                    NY'X FS TQI... HQTHP.",
#  '                         ',
#  '                                             IFNXD',
#  '                        (IJXUJWFYJ KTW XRFQQ YFQP)',
#  '                    QTAJQD YMTZLM. F QTAJQD... HQTHP.',
#  '                         ',
#  '          LFYXGD KNSFQQD RFSFLJX YT XJY YMJ HQTHP GFHP TS YMJ RFSYQJ.',
#  '                         ',
#  '          LFYXGD YFPJX F XJFY.',
#  '                         ',
#  '          F QTSL XNQJSY GJFY.',
#  '                         ',
#  "                                             IFNXD (HTSY'I)",
#  "                    BJ MFAJS'Y RJY KTW RFSD DJFWX.",
#  '                         ',
#  '                                             LFYXGD',
#  '                        (FS FZYTRFYNH WJKQJC)',
#  '                    KNAJ DJFWX SJCY STAJRGJW.',
#  '                         ',
#  "          YMJ UWJHNXNTS TK LFYXGD'X FSXBJW NX FHZYJQD JRGFWWFXXNSL.",
#  '                         ',
#  '                                                SNHP',
#  '                                          (FGWZUYQD)',
#  '                    YJF?',
#  '                         ',
#  '                                             LFYXGD',
#  '                                       (IDNSL)',
#  '                    YMFSP DTZ TQI XUTWY.',
#  '                         ',
#  '                                             IFNXD',
#  '                                       (FQXT RTWYNKNJI)',
#  '                    IFWQNSL YMFSP DTZ.',
#  '                         ',
#  '          SNHP UTZWX; FSI YMJD FQQ XNY XYNKKQD, XNUUNSL YMJNW YJF.',
#  '                         ',
#  '          F QTSL, YJWWNGQJ XNQJSHJ...',
#  '                         ',
#  '          XZIIJSQD SNHP XYFSIX.',
#  '                         ',
#  '                                             SNHP',
#  '                    N OZXY SJJI YT... UTU NSYT YTBS.',
#  '                         ',
#  '                                             LFYXGD',
#  '                                       (MTWWNKNJI)',
#  '                    YTBS...?',
#  '                                                                     63.',
#  '                         ',
#  '                         ',
#  '                                             SNHP',
#  "                    YMJ ANQQFLJ; N'QQ GJ WNLMY GFHP.",
#  '                         ',
#  '          FX SNHP QJFAJX, LFYXGD KTQQTBX.',
#  '                         ',
#  '                                             LFYXGD',
#  "                    N'AJ LTY YT XUJFP YT DTZ...!",
#  '                         ',
#  '                         ',
#  "          NSY. SNHP'X GZSLFQTB - PNYHMJS - HTSYNSZTZX",
#  '                         ',
#  '          BNQIQD KTQQTBNSL SNHP, LFYXGD BMNXUJWX RNXJWFGQD:',
#  '                         ',
#  '                                             LFYXGD',
#  '                    TM, LTI! YMNX NX F RNXYFPJ, F',
#  '                    YJWWNGQJ, YJWWNGQJ RNXYFPJ...',
#  '                         ',
#  '                                             SNHP',
#  "                    DTZ'WJ OZXY JRGFWWFXXJI, YMFY'X",
#  "                    FQQ... IFNXD'X JRGFWWFXXJI YTT.",
#  '                         ',
#  '                                             LFYXGD',
#  "                    XMJ'X JRGFWWFXXJI?",
#  '                         ',
#  '                                             SNHP',
#  '                    OZXY FX RZHM FX DTZ FWJ.',
#  '                         ',
#  '                                             LFYXGD',
#  "                    ITS'Y YFQP XT QTZI!",
#  '                         ',
#  '                                             SNHP',
#  "                    DTZ'WJ FHYNSL QNPJ F QNYYQJ GTD!",
#  "                    DTZ'WJ WZIJ. IFNXD'X NS YMJWJ FQQ",
#  '                    FQTSJ FSI...',
#  '                         ',
#  '          LFYXGD WFNXJX MNX MFSI, QTTPX FY SNHP WJUWTFHMKZQQD, FSI',
#  '          MJFIX GFHP NSYT YMJ QNANSL WTTR.',
#  '                         ',
#  '                         ',
#  "          JCY. SNHP'X GZSLFQTB - HTSYNSZTZX",
#  '                         ',
#  '          SNHP WZSX KTW F YWJJ BMTXJ QJFAJX XMNJQI FLFNSXY YMJ WFNS.',
#  '                         ',
#  '                              SNHP (A.T.)',
#  "                    QTTPNSL TAJW RD XYTWD XT KFW, N'R",
#  '                    WJRNSIJI YMFY KTW YMJ XJHTSI YNRJ',
#  '                    YMFY XZRRJW...',
#  '                         ',
#  '          BNIJ: SNHP GJSJFYM YMJ YWJJ QTTPX YNSD, FSI AJWD FQTSJ.',
#  '                         ',
#  '                              SNHP (A.T.)',
#  "                    N BFX LZFWINSL TYMJW UJTUQJ'X",
#  '                    XJHWJYX.',
#  '                                                                  64.',
#  '                         ',
#  '                         ',
#  "          NSY. SNHP'X GZSLFQTB - QNANSL WTTR - IFD",
#  '                         ',
#  '          QFYJW. SNHP WJ-JSYJWX, GJIWFLLQJI, WFNS-XTFPJI.',
#  '                         ',
#  '                              SNHP (A.T.)',
#  '                    TSHJ FLFNS N BFX BNYMNS...',
#  '                         ',
#  "          MJ YWNJX YT LJY LFYXGD FSI IFNXD'X FYYJSYNTS, YT ST FAFNQ...",
#  '          YMJ QTAJWX FWJ HTRUQJYJQD FSI YTYFQQD FGXTWGJI NS JFHM TYMJW.',
#  '                         ',
#  '                              SNHP (A.T.)',
#  '                    FSI BNYMTZY...',
#  '                         ',
#  '          SNHP GFSLX UTYX NS YMJ XNSP - XYNQQ STYMNSL.',
#  '                         ',
#  '          MJ HQJFWX MNX YMWTFY:',
#  '                         ',
#  '                                             SNHP',
#  '                    NYX... XYTUUJI WFNSNSL.',
#  '                         ',
#  '          IFNXD YZWSX; F WFINFSY XRNQJ. JAJWD AJXYNLJ TK JRGFWWFXXRJSY',
#  '          GJYBJJS IFNXD FSI LFYXGD NX LTSJ. LFYXGD QNYJWFQQD LQTBX.',
#  '                         ',
#  '                                              LFYXGD',
#  '                    DJX, NY MFX...',
#  '                                       (YT IFNXD)',
#  "                    MFXS'Y NY?",
#  '                         ',
#  '          MJ XYFSIX, BFQPX YT YMJ BNSITB FSI QTTPX TZY FHWTXX YMJ GFD.',
#  '                         ',
#  "                                              LFYXGD (HTSY'I)",
#  '                    BMFY IT DTZ YMNSP TK YMFY, IFNXD?',
#  '                    HTRJ QTTP.',
#  '                         ',
#  '          IFNXD OTNSX LFYXGD FSI YMJD XYJU TZY TSYT YMJ UTWHM YTLJYMJW.',
#  '                         ',
#  '                         ',
#  "          JCY. SNHP'X GZSLFQTB - UTWHM - HTSYNSZTZX",
#  '                         ',
#  '                                             IFNXD',
#  '                    QTTP. NYX RD MTZXJ. OZXY YMJWJ',
#  '                    FHWTXX YMJ GFD...',
#  '                         ',
#  "          LFYXGD FSI IFNXD'X JDJX RJJY.",
#  '                         ',
#  '                                             LFYXGD',
#  '                    N PSTB. N MFAJ YMJ XFRJ ANJB KWTR',
#  '                    RD UQFHJ.',
#  '                         ',
#  '                                             IFNXD',
#  "                    BMJWJ'X DTZW UQFHJ?",
#  '                         ',
#  '          LFYXGD YZWSX GFHP YT SNHP.',
#  '                                                                    65.',
#  '                         ',
#  '                         ',
#  '                                             LFYXGD',
#  '                    SNHP, N BFSY DTZ FSI IFNXD GTYM YT',
#  "                    XJJ RD MTZXJ. N'I QNPJ YT XMTB MJW",
#  '                    FWTZSI.',
#  '                         ',
#  '                                             SNHP',
#  '                    FWJ DTZ XZWJ DTZ BFSY RJ YT HTRJ?',
#  '                         ',
#  '                                             LFYXGD',
#  '                    FGXTQZYJQD, TQI XUTWY. FGXTQZYJQD.',
#  '                         ',
#  '                         ',
#  "          JCY. LFYXGD'X HFXYQJ - KWTSY LFYJX - IFD",
#  '                         ',
#  '          XJWAFSYX XBNSL TUJS NAD-HTAJWJI LFYJX...',
#  '                         ',
#  '                                             LFYXGD',
#  '                                       (UWTZIQD)',
#  '                    N MFI YMJ LFYJX GWTZLMY NS KWTR F',
#  '                    HFXYQJ NS STWRFSID.',
#  '                         ',
#  "          WJAJFQ: LFYXGD'X HFXYQJ LQNXYJSNSL NS YMJ XZSQNLMY.",
#  '                         ',
#  '          HQTXJ TS: IFNXD. F IJQNLMYJI HWD.',
#  '                         ',
#  '                                             IFNXD',
#  '                    TM, OFD...!? NYX XT LWFSI!',
#  '                         ',
#  '                                             LFYXGD',
#  '                    IT DTZ QNPJ NY?',
#  '                         ',
#  '                                             IFNXD',
#  '                    N QTAJ NY...! GZY MTB IT DTZ QNAJ',
#  '                    MJWJ FQQ FQTSJ?',
#  '                         ',
#  '                                             LFYXGD',
#  "                    N ITS'Y. N PJJU NY FQBFDX KZQQ TK",
#  '                    NSYJWJXYNSL, HJQJGWFYJI UJTUQJ...',
#  '                         ',
#  '          FX IFNXD WZSX FMJFI, LFYXGD RZWRZWX YT SNHP.',
#  '                         ',
#  "                                             LFYXGD (HTSY'I)",
#  "                    RD MTZXJ QTTPX BJQQ ITJXS'Y NY? XJJ",
#  '                    MTB YMJ BMTQJ KWTSY HFYHMJX YMJ',
#  '                    QNLMY QNPJ YMFY?',
#  '                         ',
#  '          IFNXD DJQQX GFHP...',
#  '                         ',
#  '                                             IFZXD',
#  '                    HTRJ TS DTZ YBT! N BFSY YMJ WTDFQ',
#  '                    YTZW!',
#  '                         ',
#  '                                                                         INXXTQAJ YT:',
#  '                                                                     66.',
#  '                         ',
#  '                         ',
#  "          JCY. LFYXGD'X HFXYQJ - LFWIJSX - IFD",
#  '                         ',
#  '          LFYXGD MFX YWFSXKTWRJI NSYT F LTTI-SFYZWJI XMTB-TKK, MZWWDNSL',
#  '          SNHP FSI IFNXD YMWTZLM F RFEJ TK KFSYFXYNHFQ LFWIJSX, UFXY',
#  '          RFLSNKNHJSY KTZSYFNSX FSI NSYT MNX HFXYQJ...',
#  '                         ',
#  '                         ',
#  "          NSY. LFYXGD'X HFXYQJ - PNYHMJS - IFD",
#  '                         ',
#  '          LFYGXD XMTBX TKK MNX GWFSI SJB TWFSLJ-OZNHJW.',
#  '                         ',
#  '                                             LFYGXD',
#  '                    DTZ RZXY ZSIJWXYFSI, N QNPJ FQQ',
#  '                    YMNSLX YMFY FWJ RTIJWS.',
#  '                         ',
#  '          IFNXD WJFINJX F HTHPYFNQ XMFPJW GJSJFYM YMJ XUTZY TK YMJ',
#  '          LNFSY XNQAJW TWFSLJ OZNHJ RFHMNSJ.',
#  '                         ',
#  '                                             LFYXGD',
#  '                    NK DTZ UWJXX YMNX GZYYTS MJWJ, YMJ',
#  '                    TWFSLJX XMTTY YMWTZLM MJWJ, FWJ',
#  '                    HWZXMJI YMJWJ... YMJ OZNHJ TK 200',
#  '                    TWFSLJX JCYWFHYJI NS TSJ MTZW...!',
#  '                         ',
#  '          LFYXGD UWJXXJX, YMJ RFHMNSJ LWTFSX FSI OZNHJ XUQFXMJX TZY!',
#  '                         ',
#  '                                                                         INXXTQAJ YT:',
#  '                         ',
#  '                         ',
#  "          JCY. LFYXGD'X GJFHM - INANSL UTSYTTS - QFYJ FKYJWSTTS",
#  '                         ',
#  '          IFNXD, SNHP FSI LFYXGD IWZSPJSQD IWNAJ LTQK GFQQX TZY YTBFWI',
#  "          YMJ GFD. SNHP KNQRX TS YMJ BTWQI'X KNWXY MTRJ-HFRHTWIJW...",
#  '                         ',
#  '                                             LFYXGD',
#  '                    NYX F WJRFWPFGQJ QNYYQJ HFRJWF--',
#  '                    QFYJXY IJXNLS.',
#  '                         ',
#  '          BMNQJ, SJFWGD, F GZYQJW NS F GTFY XYFSIX BFYHM TAJW F',
#  '          XUNSSNSL LWFRTUMTSJ FSI GTYYQJX TK HMFRUFLSJ...',
#  '                         ',
#  '                                             IFNXD',
#  "                    DTZ IT PSTB, N'R F HMFRUNTS LTQKJW,",
#  "                    ITS'Y DTZ? MJWJ, N'QQ XMTB DTZ MTB",
#  '                    NYX ITSJ.',
#  '                         ',
#  '          HWFHP! IFNXD HZYX F RFWAJQTZX XBNSL, XSFUUNSL F HQZG NS YBT!',
#  '                         ',
#  '          XMJ KFQQX NSYT LFYXGD FWRX...',
#  '                         ',
#  '          SNHP KNQRX...',
#  '                                                                    67.',
#  '                         ',
#  '                         ',
#  '                                             LFYXGD',
#  '                    XMJ QTTPX QNPJ XMJ HTZQI GJ TS YMJ',
#  "                    HTAJW TK ATLZJ, ITS'Y DTZ YMNSP...?",
#  '                         ',
#  '                                                                         INXXTQAJ YT:',
#  '                         ',
#  '                         ',
#  "          NSY. LFYXGD'X HFXYQJ - LWFSI GFQQWTTR - JFWQD JAJSNSL",
#  '                         ',
#  '          LFYXGD FSI SNHP YWFNQ GJMNSI IFNXD, HWTXXNSL YMJ GFQQWTTR.',
#  '                         ',
#  '          IFNXD, HMFRUFLSJ NS MFSI, XUTYX YMJ XTFWNSL GFQQWTTR TWLFS.',
#  '                         ',
#  '                                             IFNXD',
#  '                    TM...! NYX GJFZYNKZQ.',
#  '                         ',
#  '                                             LFYXGD',
#  '                    NYX F HZXYTR BZWQNYEJW.',
#  '                         ',
#  '                                             IFNXD',
#  '                    HFS FSDTSJ UQFD NY?',
#  '                         ',
#  '                                             LFYXGD',
#  '                    PQNUXUWNSLJW HFS.',
#  '                        (YT MNX KTTYRJS)',
#  '                    XTRJTSJ BFPJ JBNSL!',
#  '                         ',
#  '          IFNXD YBNWQX WTZSI, TAJWOTDJI...',
#  '                         ',
#  '                                             IFNXD',
#  '                    RZXNH! FSI BJ HFS IFSHJ FQQ SNLMY!',
#  '                         ',
#  '                                             LFYXGD',
#  "                    JBNSL'X F XDRUMTSNH LJSNZX, MJ HFS",
#  '                    UQFD FSDYMNSL...!',
#  '                         ',
#  '          IFNXD WZSX ZU YMJ XYFNWX FSI HFQQX ITBS...',
#  '                         ',
#  '                                             IFNXD',
#  '                    YMJS N IJRFSI F HMFWQJXYTS!',
#  '                         ',
#  '          LFYXGD LFEJX ZU FKYJW IFNXD, FSI HTSKNIJX NS SNHP...',
#  '                         ',
#  '                                             LFYXGD',
#  '                        (FX NK NS F IWJFR)',
#  '                    XMJ RFPJX NY QTTP XT XUQJSINI,',
#  "                    ITS'Y DTZ YMNSP TQI XUTWY?",
#  '                         ',
#  '                                                                         INXXTQAJ YT:',
#  '                         ',
#  '                         ',
#  "          NSY. LFYXGD'X HFXYQJ. LFYXGD'X GJIWTTR - JAJSNSL",
#  '                         ',
#  '          SNHP FSI IFNXD KTQQTB LFYXGD NSYT YMJ GJIWTTR...',
#  '                                                                  68.',
#  '                         ',
#  '                         ',
#  '          LFYXGD GTZSIX FMJFI, XYFWYNSL ZU F XUNWFQ XYFNW... MJ YMWTBX',
#  '          TUJS F RFXXNAJ HFGNSJY, WJAJFQNSL F UWNXR TK XZNYX, IWJXXNSL-',
#  '          LTBSX, BFYHMJX FSI YNJX.',
#  '                         ',
#  '                                             LFYXGD',
#  "                    N'AJ LTY F RFS NS JSLQFSI BMT GZDX",
#  '                    RJ HQTYMJX...!',
#  '                         ',
#  '          MJ UQFDKZQQD YTXXJX IFNXD F GTFYJW-MFY...',
#  '                         ',
#  "                                             LFYXGD (HTSY'I)",
#  '                    XTRJYMNSL KTW YMJ QFID...',
#  '                         ',
#  '          YMJS MJ GJLNSX DFSPNSL ITBS XMNWYX FSI YTXXNSL YMJR TAJW YMJ',
#  '          WFNQ YT IFNXD...',
#  '                         ',
#  '                                             IFNXD',
#  "                    N'AJ SJAJW XJJS FSDYMNSL QNPJ NY!",
#  '                         ',
#  '                                             LFYXGD',
#  '                    MJ XJSIX TAJW F XJQJHYNTS FY YMJ',
#  '                    GJLNSSNSL TK JFHM XJFXTS...',
#  '                         ',
#  '                                             IFNXD',
#  '                    OFD!',
#  '                         ',
#  '          BNYM JAJW-NSHWJFXNSL JSYMZXNFXR!',
#  '                         ',
#  '                                             LFYXGD',
#  '                    YMJXJ FWJ XNQP! QNSJS! NSINFS',
#  '                    KQFSSJQ! JLDUYNFS HTYYTS!',
#  '                         ',
#  '          IFNXD, NSYTCNHFYJI, QJFUX TS YMJ GJI, FWRX TZYXYWJYHMJI...',
#  '                         ',
#  '                                             IFNXD',
#  "                    ST, OFD... DTZ'QQ WZNS YMJR!",
#  '                                       (YT SNHP)',
#  "                    SNHPD! MJ'X F RFIRFS!",
#  '                         ',
#  '          RTWJ FSI RTWJ FSI RTWJ XMNWYX KQTFY ITBS...',
#  '                         ',
#  '          YMJ WZRGQJ TK INXYFSY YMZSIJW.',
#  '                         ',
#  '          HQTXJ TS: IFNXD. YNRJ XQTBX FX XMNWYX KQZYYJW, QNPJ LNFSY',
#  '          XSTBKQFPJX, ITBS YTBFWI MJW. XQTBQD, VZNJYQD, MJW RNWYM',
#  '          YWFSXKTWRX YT XTGX... XMJ MNIJX MJW KFHJ NS XMNWYX...',
#  '                         ',
#  '          LFYXGD JFXJX ITBS YMJ XYFNWX FSI SJXYQJX GJXNIJ IFNXD, YFPNSL',
#  '          MJW YJFW-XYWJFPJI KFHJ NS MNX MFSIX...',
#  '                         ',
#  '                                             LFYXGD',
#  '                    BMFY NX NY?',
#  '                                                                  69.',
#  '                         ',
#  '                         ',
#  '                                              IFNXD',
#  "                    NY'X OZXY... NY RFPJX RJ XFI,",
#  '                    GJHFZXJ...',
#  '                         ',
#  "          IFNXD LQFSHJX NS SNHP'X INWJHYNTS...",
#  '                         ',
#  '                                             LFYXGD',
#  '                    BMD?',
#  '                         ',
#  '                                             IFNXD',
#  '                    ...GJHFZXJ...',
#  '                         ',
#  '          F XZXUJSIJI RTRJSY; IFNXD NX NSHFUFGQJ TK XUJFPNSL MJW MJFWY.',
#  '                         ',
#  '                              SNHP (A.T.)',
#  '                    KNAJ QTXY DJFWX XYWZLLQJI TS',
#  "                    IFNXD'X QNUX. GZY FQQ XMJ HTZQI",
#  '                    RFSFLJ BFX...',
#  '                         ',
#  '                                             IFNXD',
#  "                    NY'X OZXY... GJHFZXJ N'AJ SJAJW",
#  '                    XJJS XZHM GJFZYNKZQ XMNWYX GJKTWJ.',
#  '                         ',
#  '                                             LFYXGD',
#  "                    NK NY BFXS'Y KTW YMJ RNXY BJ HTZQI",
#  '                    XJJ YMJ LWJJS QNLMY...',
#  '                         ',
#  '                                             IFNXD',
#  '                    BMFY LWJJS QNLMY?',
#  '                         ',
#  '                                             LFYXGD',
#  '                    YMJ TSJ YMFY GZWSX FQQ SNLMY FY YMJ',
#  '                    JSI TK DTZW ITHP.',
#  '                         ',
#  '          FX LFYXGD FSI IFNXD XYFWJ TZY FHWTXX YMJ GFD...',
#  '                         ',
#  '                              SNHP (A.T.)',
#  '                    UTXXNGQD, NY MFI THHZWWJI YT LFYXGD',
#  '                    YMFY YMJ HTQTXXFQ XNLSNKNHFSHJ TK',
#  '                    YMFY QNLMY MFI AFSNXMJI KTWJAJW.',
#  '                    STB, NY BFX TSHJ FLFNS OZXY F LWJJS',
#  '                    QNLMY TS F ITHP. MNX HTZSY TK',
#  '                    JSHMFSYJI TGOJHYX MFI INRNSNXMJI GD',
#  '                    TSJ.',
#  '                         ',
#  '          SNHP, NRUJQQJI YT WJRNSI IFNXD FSI LFYXGD TK MNX UWJXJSHJ,',
#  '          JRJWLJX KWTR YMJ XMFITBX FSI IJXHJSIX YMJ XUNWFQ XYFNWHFXJ.',
#  '                         ',
#  '          MJ MTQIX F UMTYT TK FS JQIJWQD RFS NS DFHMYNSL HTXYZRJ...',
#  '                         ',
#  '                                             SNHP',
#  "                    BMT'X YMNX? DTZW KFYMJW?",
#  '                                                                    70.',
#  '                         ',
#  '                         ',
#  '                                             LFYXGD',
#  "                    ST, ST.. YMFY'X RW. IFS HTID, TQI",
#  "                    XUTWY... MJ'X IJFI STB. MJ ZXJI YT",
#  '                    GJ RD GJXY KWNJSI DJFWX FLT.',
#  '                         ',
#  '          IFNXD OTNSX SNHP FY YMJ GTYYTR TK YMJ XYJUX. NS YMJ UMTYT',
#  '          BNYM HTID, FQXT NS DFHMYNSL HTXYZRJ, NX F DTZSL LFYXGD...',
#  '                         ',
#  '                                             IFNXD',
#  '                                       (YJFXJX)',
#  '                    DTZ SJAJW YTQI RJ DTZ MFI F',
#  '                    UTRUFITZW... TW F DFHMY.',
#  '                         ',
#  '          LFYXGD MFXYNQD UQZHPX F XHWFUGTTP KWTR F WTB TS MNX IJXP...',
#  '                         ',
#  '                                              LFYXGD',
#  '                    N BFSY YT XMTB DTZ XTRJYMNSL...',
#  "                    QTTP, MJWJ'X F QTY TK HQNUUNSLX,",
#  '                    FGTZY DTZ.',
#  '                         ',
#  '          YMJD FIRNWJ F XHWFUGTTP YTLJYMJW.',
#  '                         ',
#  '                                             IFNXD',
#  '                                       (YTZHMJI)',
#  '                    DTZ XFAJI RD QJYYJWX...',
#  '                         ',
#  '                                             LFYXGD',
#  '                    YMNX BFX RD KNWXY UMTYT TK DTZ.',
#  '                         ',
#  '          FX IFNXD KQNUX YMWTZLM FSI UZQQX TZY FS TQI QJYYJW TK MJWX,',
#  '          BJ MJFW MJW WJFINSL YMJ QJYYJW NS FGXYWFHY ATNHJTAJW:',
#  '                         ',
#  '                              IFNXD (A.T.)',
#  '                    BJ HFSY QTXJ JFHM TYMJW FSI QJY FQQ',
#  '                    YMNX LQTWNTZX QTAJ JSI NS STYMNSL.',
#  "                    HTRJ MTRJ, N'QQ GJ MJWJ BFNYNSL FSI",
#  '                    MTUNSL, KTW JAJWD QTSL IWJFR TK DTZ',
#  '                    YT HTRJ YWZJ... HTRJ MTRJ OFD...',
#  '                         ',
#  '          GGGWWWSSSLLL! YMJ UMTSJ XMWNQQX.',
#  '                         ',
#  '                                                LFYXGD',
#  '                    JCHZXJ RJ.',
#  '                         ',
#  '          LFYXGD HWTXXJX YMJ WTTR, XSFYHMJX ZU YMJ WJHJNAJW, FSI YZWSX',
#  '          FBFD... MJ QTBJWX MNX ATNHJ.',
#  '                         ',
#  "                              LFYXGD (NSYT UMTSJ) (HTSY'I)",
#  "                    BJQQ N HFS'Y YFQP STB TQI XUTWY...",
#  '                         ',
#  "          FX YMJ YNRGWJ TK LFYXGD'X ATNHJ IFWPJSX BJ UZXM HQTXJW.",
#  '                         ',
#  "                              LFYXGD (NSYT UMTSJ) (HTSY'I)",
#  '                     N XFNI F XRFQQ YTBS.',
#  '                                                                       71.',
#  '                         ',
#  '                         ',
#  "          JHZ: LFYXGD'X JDJX SFWWTB.",
#  '                         ',
#  "                                 LFYXGD (NSYT UMTSJ) (HTSY'I)",
#  '                       MJ RZXY PSTB BMFY F XRFQQ YTBS NX.',
#  '                         ',
#  '          GTTTTRRR! F XYTWRNSL BNSI GFSLX TUJS YMJ KWJSHM BNSITBX!',
#  '                         ',
#  '          FX SNHP RTAJX YT XMZY YMJR, MJ LQNRUXJX LFYXGD...',
#  '                         ',
#  "                                 LFYXGD (NSYT UMTSJ) (HTSY'I)",
#  '                                          (KWNLMYJSNSL)',
#  "                       BJQQ, MJ'X ST ZXJ YT ZX NK IJYWTNY",
#  '                       NX MNX NIJF TK F XRFQQ YTBS...',
#  '                         ',
#  "          LFYXGD WNSLX TKK FGWZUYQD, FSI HFYHMJX SNHP'X JDJ - F YJSXJ",
#  ...]

# %% [markdown]
# ### Clean the text by removing punctuation and numbers since those aren't encrypted

# %%
import re

cleaned = data3\
    .map(lambda x: re.sub(r'[^\D]', ' ', x))\
        .map(lambda y: re.sub(r'[^\w\s]', ' ', y))\
            .map(lambda z: re.sub('_', '', z))\
                .map(lambda word: word.strip())

cleaned.collect()
# Out:
# ['',
#  'OTWIFS  T X',
#  'N ITS Y PSTB  XMJ BTZQIS Y YJQQ RJ',
#  '',
#  'GZY GJKTWJ YMJ QJYYJW INXFUUJFWX HTRUQJYJQD BJ WJFI TSJ RTWJ',
#  'QNSJ   YMJ YWZYM NX',
#  '',
#  'INXXTQAJ YT',
#  '',
#  '',
#  'JCY  QTZNXANQQJ HMZWHM   KWTSY XYJUX   QFYJ FKYJWSTTS',
#  '',
#  'IFNXD FSI YTR  SJBQD RFWWNJI  UTXJ KTW UMTYTX',
#  '',
#  'OTWIFS  T X',
#  'FSDBFDX  YMFY IFD  FY KNAJ T HQTHP',
#  'IFNXD KFDJ RFWWNJI YTR GZHMFSFS',
#  'BNYM RTWJ UTRU FSI HNWHZRXYFSHJ',
#  'YMFS QTZNXANQQJ MFI JAJW XJJS',
#  '',
#  'INXXTQAJ YT',
#  '',
#  '',
#  'JCY  YNRJX XVZFWJ   SNLMY',
#  '',
#  'OTWIFS FSI SNHP XYWTQQ GJSJFYM YMJ XTFWNSL JQJHYWNH XNLSX',
#  '',
#  'OTWIFS',
#  'FKYJW YMJ MTSJDRTTS  N XFB YMJR NS',
#  'XFSYF GFWGFWF  NY BFX YTZHMNSL',
#  'FHYZFQQD',
#  'RTWJ',
#  '',
#  '',
#  'OTWIFS  HTSY I',
#  'N I SJAJW XJJS F LNWQ XT NS QTAJ',
#  'BNYM MJW MZXGFSI',
#  'RZXJX HDSNHFQQD',
#  'F BJJP QFYJW  YTR HWFXMJI MNX HFW',
#  'YMJ LNWQ BNYM MNR BFX F HMFRGJWRFNI',
#  'FY YMJ XFSYF GFWGFWF MTYJQ  NY LTY',
#  'NSYT FQQ YMJ UFUJWX',
#  '',
#  'FX OTWIFS FSI SNHP FUUWTFHM YMJ HZWG  BFNYNSL KTW F HFG  SNHP',
#  'YZWSX YT OTWIFS  MJ X XYWZHP GD F    XZIIJS  UZEEQJI YMTZLMY',
#  '',
#  'SNHP',
#  'NY X F XYWFSLJ HTNSHNIJSHJ  NXS Y',
#  'NY  LFYXGD X MTZXJ GJNSL OZXY',
#  'FHWTXX YMJ GFD',
#  '',
#  'OTWIFS BMNWQX WTZSI',
#  '',
#  'OTWIFS',
#  'NY X ST HTNSHNIJSHJ  MJ GTZLMY YMFY',
#  'MTZXJ YT GJ SJFW MJW  MJ YMWJB FQQ',
#  'YMTXJ UFWYNJX MTUNSL XMJ I BFSIJW',
#  'NS TSJ SNLMY  MJ HTSXYFSYQD FXPJI',
#  'FGTZY IFNXD    N BFX YMJ KNWXY TSJ',
#  'BMT PSJB MJW',
#  '',
#  'SNHP YFPJX YMNX NS  FX NK XJJNSL LFYXGD KTW YMJ KNWXY YNRJ',
#  '',
#  'SNHP',
#  'FQQ YMFY KTW F LNWQ MJ MFXS Y XJJS',
#  'NS KNAJ DJFWX     FSI STB MJ OZXY',
#  'BFSYX RJ YT MFAJ MJW KTW YJF',
#  'YT MNRXJQK',
#  'YMJ RTIJXYD TK NY',
#  '',
#  'OTWIFS',
#  'PNSI TK YFPJX DTZW GWJFYM FBFD',
#  'ITJXS Y NY',
#  '',
#  'F HFG UZQQX ZU  FSI SNHP TUJSX YMJ ITTW',
#  '',
#  '',
#  'NSY  YFCN   HTSYNSZTZX',
#  '',
#  'OTWIFS XQNIJX NS',
#  '',
#  'YFCN IWNAJW',
#  'JAJSNSL XBJJYMJFWYX  BMJWJ YT',
#  '',
#  'OTWIFS',
#  'QTSL NXQFSI  UQJFXJ',
#  '',
#  '',
#  '',
#  'SNHP',
#  'FSI DTZ YMNSP N XMTZQI  N RJFS',
#  'ITJX IFNXD BFSY YT XJJ LFYXGD',
#  '',
#  'OTWIFS',
#  'F XYJWS BMNXUJW',
#  'XMJ X FGXTQZYJQD STY YT PSTB  DTZ',
#  'FWJ OZXY XZUUTXJI YT NSANYJ MJW',
#  'TAJW XT MJ HFS  MFUUJS YT IWTU GD',
#  '',
#  'HQTXJ TS  SNHP  ZSXZWJ',
#  '',
#  'SNHP  A T',
#  'N WJRJRGJW KJJQNSL YTWS  BFX NY',
#  'WNLMY YT GWNSL RD HTZXNS IFNXD  F',
#  'RFWWNJI BTRFS  YTLJYMJW BNYM F RFS',
#  'N MFWIQD PSJB',
#  '',
#  'FX SNHP BTSIJWX  YMJ YFCN KQTFYX FHWTXX YNRJX XVZFWJ  ZSIJW',
#  'YMJ HTTQ JDJX TK YMJ RFS NS YMJ FWWTB XMNWY',
#  '',
#  'INXXTQAJ YT',
#  '',
#  '',
#  'JCY  INWY YWFHP YT SNHP X GZSLFQTB   SNLMY',
#  '',
#  'SNHP X YFCN UZQQX UFXY LFYXGD X RFSXNTS  FGQFEJ BNYM QNLMY',
#  '',
#  'SNHP  A T',
#  'BMJS N WJYZWSJI MTRJ  LFYXGD X BFX',
#  'QNY  KWTR YTBJW YT HJQQFW  FX NK',
#  'KTW FSTYMJW BNQI UFWYD  GZY',
#  'YMJWJ BFXS Y F XTZSI',
#  '',
#  '',
#  'JCY  SNHP X GZSLFQTB   SNLMY',
#  '',
#  'FX SNHP X YFCN LWTFSX FBFD  LFYXGD FUUJFWX XYWNINSL YMWTZLM',
#  'YMJ NQQZRNSFYJI YWJJX YTBFWI SNHP',
#  '',
#  'SNHP',
#  'DTZW UQFHJ QTTPX QNPJ YMJ BTWQI X',
#  'KFNW    TW HTSJD NXQFSI',
#  '',
#  'LFYXGD',
#  'YJWWNGQD FSCNTZX',
#  'FM  ITJX NY  N AJ    N AJ OZXY GJJS',
#  'LQFSHNSL NSYT XTRJ WTTRX    QJY X',
#  'LT YT HTSJD NXQFSI  TQI XUTWY  BJ',
#  'HFS YFPJ RD HFW',
#  '',
#  'SNHP',
#  'NY X YTT QFYJ YTSNLMY',
#  '',
#  '',
#  '',
#  'LFYXGD',
#  'TW BJ HFS YFPJ F UQZSLJ NS YMJ',
#  'XBNRRNSL UTTQ  N MFAJS Y RFIJ ZXJ',
#  'TK NY FQQ XZRRJW',
#  '',
#  'SNHP',
#  'N RZXY LT YT GJI',
#  '',
#  'LFYXGD QTTPX HWJXYKFQQJS  SNHP UZYX MNR TZY TK MNX RNXJWD',
#  '',
#  'SNHP  HTSY I',
#  'MFUUD YT IT NY  OFD   N R LTNSL YT',
#  'HFQQ IFNXD FSI NSANYJ MJW YT YJF',
#  '',
#  'LFYXGD',
#  'TM  YMFY X FQWNLMY  N ITS Y BFSY YT',
#  'UZY DTZ YT FSD YWTZGQJ',
#  '',
#  'SNHP',
#  'BMFY IFD BTZQI XZNY DTZ',
#  '',
#  'LFYXGD',
#  'BMFY IFD BTZQI XZNY DTZ     N ITS Y',
#  'BFSY YT UZY DTZ YT FSD YWTZGQJ',
#  '',
#  'SNHP',
#  'IFD FKYJW YTRTWWTB FQWNLMY',
#  '',
#  'LFYXGD',
#  'IFD FKYJW YTRTWWTB  BJQQ  N I',
#  'N I BFSY YT LJY YMJ LWFXX HZY',
#  '',
#  'YMJD GTYM QTTP FY YMJ LWFXX   YMJWJ NX F XMFWU QNSJ BMJWJ',
#  'SNHP X WFLLJI QFBS JSIX FSI LFYXGD X RFSNHZWJI TSJ GJLNSX',
#  '',
#  'LFYXGD  HTSY I',
#  'YMJWJ X FSTYMJW QNYYQJ YMNSL    N',
#  'YMTZLMY   QTTP MJWJ  TQI XUTWY',
#  'DTZ ITS Y RFPJ RZHM RTSJD  IT DTZ',
#  '',
#  'SNHP',
#  'STY WJFQQD',
#  '',
#  'LFYXGD',
#  'NK DTZ QQ UFWITS RD    DTZ XJJ  N',
#  'HFWWD TS F QNYYQJ GZXNSJXX TS YMJ',
#  'XNIJ   F XTWY TK XNIJQNSJ   DTZ',
#  'ZSIJWXYFSI BMFY N R XFDNSL WNLMY',
#  'DTZ WJ XJQQNSL GTSIX  FWJS Y DTZ',
#  'TQI XUTWY',
#  '',
#  'SNHP',
#  'YWDNSL YT',
#  '',
#  '',
#  '',
#  'LFYXGD',
#  'BJQQ  YMNX RNLMY NSYJWJXY DTZ    NY',
#  'MFUUJSX YT GJ F WFYMJW HTSKNIJSYNFQ',
#  'XTWY TK YMNSL    GZY DTZ RNLMY UNHP',
#  'ZU F SNHJ GNY TK RTSJD',
#  '',
#  'SNHP',
#  'N AJ LTY RD MFSIX KZQQ',
#  '',
#  'LFYXGD X KFHJ KFQQX',
#  '',
#  'LFYXGD',
#  'DTZ BTZQIS Y MFAJ YT IT FSD',
#  'GZXNSJXX BNYM BTQKXMJNR  N FXXZWJ',
#  'DTZ',
#  '',
#  'SNHP',
#  'ST  ST  ST    NYX F KFATW OFD  OZXY',
#  'F KFATW',
#  '',
#  'SNHP X XNSHJWNYD INXFWRX LFYXGD  F YNSD  JRGFWWFXXJI STI',
#  '',
#  'SNHP  HTSY I',
#  'MFUUD YT IT NY',
#  '',
#  'LFYXGD',
#  'F KFATW',
#  '',
#  'SNHP',
#  'DJX',
#  '',
#  'FX NK ST TSJ MFX JAJW ITSJ MNR F KFATW GJKTWJ NS MNX QNKJ',
#  '',
#  'LFYXGD',
#  'FM  WNLMY  WNLMY    LTTISNLMY',
#  '',
#  'SNHP',
#  'LTTISNLMY',
#  '',
#  'BNYM YMNX  LFYXGD YZWSX FSI XYWTQQX GFHP YTBFWI MNX GQFENSL',
#  'HFXYQJ  SNHP X LFEJ KFQQX ZUTS YMJ ZSPJRUY QFBS  MJ XRNQJX',
#  '',
#  'INXXTQAJ YT',
#  '',
#  '',
#  'JCY  SNHP X GZSLFQTB   KWTSY QFBS   IFD',
#  '',
#  'YTU XMTY  FS JSTWRTZX RTBJW HQFYYJWX YMWTZLM KWFRJ  HFWANSL',
#  'SNHP X ZSPJRUY QFBS NSYT F KWJXM  GWTFI  GFSI TK LWJJS',
#  '',
#  'WJAJFQ  FS FWRD TK LFWISIJWX LNANSL SNHP X QFBS FSI LFWIJS F',
#  'RFPJ TAJW  KWJXM UFNSY  SJB KQTBJWX  YWNRRJI MJILJX',
#  '',
#  'INXXTQAJ YT',
#  '',
#  '',
#  '',
#  'JCY  SNHP X GZSLFQTB   KWTSY QFBS   YMJ KTQQTBNSL IFD',
#  '',
#  'MJFAD WFNS STB KFQQX',
#  '',
#  'LFYXGD  IWJXXJI NS BMNYJ KQFSSJQ XZNY  XNQAJW XMNWY  FSI LTQI',
#  'YNJ  QJFIX F ITEJS ZRGWJQQF MTQINSL XJWAFSYX FHWTXX YMJ QFBS',
#  'MJWETL MTQIX FS ZRGWJQQF TAJW LFYXGD  YMJ TYMJW XJWAFSYX',
#  'XMJQYJW JCYWFAFLFSY KQTWFQ FWWFSLJRJSYX NS HWDXYFQ AFXJX',
#  '',
#  'SNHP BFYHMJX YMJ UFWFIJ YMWTZLM MNX BNSITB  TUJSNSL MNX ITTW',
#  'OZXY FX LFYXGD FWWNAJX  YMJ XJWAFSYX HTSYNSZJ NSXNIJ',
#  '',
#  'TS YMJ UTWHM  LFYXGD QTTPX FWTZSI INXYWFHYJIQD',
#  '',
#  'LFYXGD',
#  'TSJ TK YMJ UFUJWX XFNI YMJD YMTZLMY',
#  'YMJ WFNS BTZQI XYTU FGTZY KTZW  N',
#  'YMNSP NY BFX YMJ OTZWSFQ',
#  '',
#  'FS FBPBFWI GJFY',
#  '',
#  'SNHP',
#  'YMJ LWFXX QTTPX KNSJ',
#  '',
#  'LFYXGD',
#  'LWFXX',
#  '',
#  'LFYXGD QTTPX FY SNHP BNYMTZY WJFQQD HTRUWJMJSINSL  TW XJJNSL',
#  '',
#  'LFYXGD  HTSY I',
#  'BMFY LWFXX',
#  '',
#  'XZIIJS HZY YT',
#  '',
#  '',
#  'NSY  SNHP X GZSLFQTB   QNANSL WTTR   IFD',
#  '',
#  'YNLMY TS  F RFSYJQUNJHJ HQTHP  YNHPNSL NS YMJ YJSXJ XNQJSHJ',
#  '',
#  'BNIJW  YMJ WTTR NX HWTBIJI BNYM FGXZWIQD JCYWFAFLFSY KQTWFQ',
#  'FWWFSLJRJSYX  SNHP XNYX BFYHMNSL FX LFYXGD NSYJSXJQD UFHJX',
#  'YMJ XNQJSHJ XYWJYHMJX  FSI XYWJYHMJX    KNSFQQD',
#  '',
#  'LFYXGD',
#  'MFAJ DTZ LTY JAJWDYMNSL DTZ SJJI',
#  '',
#  'SNHP',
#  'UJWMFUX RTWJ KQTBJWX',
#  '',
#  'LFYXGD',
#  'N YMNSP YMJD INI F KNSJ OTG  ITS Y',
#  'DTZ',
#  '',
#  '',
#  '',
#  'SNHP',
#  'GJFZYNKZQ',
#  '',
#  'LFYXGD',
#  'DTZ YMNSP NY X YTT RZHM',
#  '',
#  'SNHP',
#  'N YMNSP NY X BMFY DTZ BFSY',
#  '',
#  'LFYXGD',
#  'N YMNSP XT YTT    XMJ QQ GJ',
#  'NRUWJXXJI  BTS Y XMJ TQI XUTWY',
#  '',
#  'SNHP',
#  'N FR',
#  '',
#  'BNYM YMNX  LFYXGD XYWFNLMYJSX MNX XZNY  XNYX  FSI MZWWNJIQD',
#  'HMJHPX MNX BFYHM  FSTYMJW QTSL XNQJSHJ',
#  '',
#  'UZXM NS TS  LFYXGD    XZIIJSQD  MJ QJFUX YT MNX KJJY',
#  '',
#  'LFYXGD',
#  'N HFS Y BFNY FQQ IFD  N R QJFANSL',
#  '',
#  'SNHP',
#  'ITS Y GJ XNQQD  NY X OZXY YBT',
#  'RNSZYJX YT KTZW',
#  '',
#  'GZY LFYXGD MJFIX KTW YMJ ITTW',
#  '',
#  'LFYXGD',
#  'STGTID X HTRNSL YT YJF  NY X YTT',
#  'QFYJ',
#  '',
#  'GJJJJJU  LFYXGD LQNRUXJX IFNXD X WTQQX WTDHJ FWWNANSL TZY',
#  'KWTSY  FSI YZWSX YT SNHP  KQZXMJI BNYM KWJXM UFSNH',
#  '',
#  'SNHP',
#  'NY X MJW',
#  '',
#  'UZXM NS TS LFYXGD  RNSI WFHNSL',
#  '',
#  '',
#  'JCY  SNHP X GZSLFQTB   IFD',
#  '',
#  'IFNXD X HMFZKKJZW IWNAJS WTQQX UZQQX ZU NS YMJ RZIID IWNAJ',
#  '',
#  'FX SNHP FXXNXYX IFNXD KWTR YMJ HFW',
#  '',
#  'IFNXD',
#  'NX YMNX FGXTQZYJQD BMJWJ DTZ QNAJ',
#  'RD IJFWJXY TSJ',
#  '',
#  'XMJ QTTPX FY MNR BNYM F RDXYJWNTZX XRNQJ',
#  '',
#  '',
#  '',
#  'IFNXD  HTSY I',
#  'BMD INI N MFAJ YT HTRJ FQTSJ  FWJ',
#  'DTZ NS QTAJ BNYM RJ',
#  '',
#  'SNHP',
#  'YMFY X YMJ XJHWJY TK HFWWFBFD',
#  'HFXYQJ',
#  'UQFDNSL FQTSL',
#  'YJQQ DTZW HMFZKKJZW YT LT KFW FBFD',
#  '',
#  'IFNXD',
#  'HTRJ GFHP NS FS MTZW  KJWINJ',
#  'LWFAJ RZWRZW',
#  'MNX SFRJ NX KJWINJ',
#  '',
#  '',
#  'NSY  SNHP X GZSLFQTB   MFQQ   IFD',
#  '',
#  'IFNXD HTSYNSZJX FMJFI NSYT YMJ QNANSL WTTR',
#  '',
#  'SNHP MFSLX GFHP FSI QNXYJSX MTUJKZQQD YT IFNXD X WJFHYNTS FY',
#  'INXHTAJWNSL LFYXGD  MJ XRNQJX FX MJ MJFWX F IJQNLMYJI',
#  '',
#  'IFNXD  T X',
#  'TM    TM  RD LTTISJXX  N    N HFS Y',
#  'GJQNJAJ NY  DTZ   INI DTZ WFSXFHP F',
#  'LWJJSMTZXJ',
#  '',
#  '',
#  'NSY  SNHP X GZSLFQTB   QNANSL WTTR   HTSYNSZTZX',
#  '',
#  'IFNXD',
#  'YT MJWXJQK',
#  'MJ NX NS QTAJ BNYM RJ',
#  '',
#  'SNHP JSYJWX  GZY NX XMTHPJI YT INXHTAJW YMFY LFYXGD NX STY',
#  'YMJWJ  IFNXD X RJWJQD GJJS FIRNWNSL YMJ KQTBJW INXUQFD',
#  '',
#  'SNHP',
#  'YMFY X KZSSD',
#  '',
#  'IFNXD',
#  'BMFY X KZSSD',
#  '',
#  'PSTHP  PSTHP  XTRJTSJ NX FY YMJ ITTW',
#  '',
#  'SNHP',
#  'TSJ RTRJSY',
#  '',
#  '',
#  'NSY  SNHP X GZSLFQTB   MFQQ   HTSYNSZTZX',
#  '',
#  'SNHP TUJSX YMJ ITTW',
#  '',
#  '',
#  '',
#  'LFYXGD  UFQJ FX IJFYM FSI XTFPJI  LQFWJX RNXJWFGQD FY SNHP',
#  '',
#  'SNHP',
#  'BMFY FWJ DTZ ITNSL',
#  '',
#  'BNYMTZY F BTWI  LFYXGD XYFQPX UFXY MNR  NSYT',
#  '',
#  '',
#  'NSY  SNHP X GZSLFQTB   QNANSL WTTR   HTSYNSZTZX',
#  '',
#  'IFNXD  MJW GFHP YT YMJ ITTW  NX XYNQQ RFWAJQQNSL FY YMJ',
#  'KQTBJWX  YMJS XMJ YZWSX  XJJX LFYXGD  F XMFWU NSYFPJ TK',
#  'GWJFYM',
#  '',
#  'YMJ WJZSNYJI QTAJWX XYFSI  XYFWNSL FY JFHM TYMJW KTW F QTSL',
#  'XZWWJFQ  RTRJSY TK INXGJQNJK  LFYXGD  JDJX QTHPJI YT IFNXD X',
#  'NX IWTBSNSL NS JRTYNTS  IFNXD KNSFQQD RFSFLJX FS FWYNKNHNFQ',
#  'HMTPNSL RZWRZW',
#  '',
#  'IFNXD',
#  'N R HJWYFNSQD LQFI YT XJJ DTZ',
#  'FLFNS',
#  '',
#  'LFYXGD X KFHJ NX KQZXMJI  YMJ AJNSX XYFSI TZY TS MNX SJHP FX',
#  'MNX QNUX XUFXR NS F MTUJQJXX FYYJRUY YT XUJFP',
#  '',
#  'KNSFQQD  MJ KNSIX BTWIX',
#  '',
#  'LFYXGD',
#  'N R    HJWYFNSQD LQFI YT XJJ DTZ FX',
#  'BJQQ',
#  '',
#  'YMJNW MJFWYX UTZSI   YMJ YJSXNTS JCHWZHNFYNSL',
#  '',
#  'JJJJPPP  YMJ XHWJFR TK F GTNQNSL PJYYQJ TKK XHWJJS GWJFPX YMJ',
#  'YJSXNTS',
#  '',
#  'HZY YT',
#  '',
#  '',
#  'NSY  SNHP X GZSLFQTB   QNANSL WTTR   IFD',
#  '',
#  'LFYXGD WJHQNSJX ZSHTRKTWYFGQD FLFNSXY YMJ RFSYJQUNJHJ  MNX',
#  'JQGTB WJXYX SJFW YMJ RFSYJQUNJHJ HQTHP  IFNXD XNYX TUUTXNYJ',
#  'KWTEJS TS YMJ JILJ TK F HMFNW',
#  '',
#  'YMJ WFYYQJ TK YMJ YJF YWFD FX SNHP JSYJWX TSQD HTSYWNGZYJX YT',
#  'YMJ FQWJFID ZSGJFWFGQJ YJSXNTS  LFYXGD RFSFLJX YT RZWRZW',
#  '',
#  'LFYXGD',
#  'BJ AJ RJY GJKTWJ',
#  '',
#  'XZIIJSQD YMJ HQTHP YNQYX FY YMJ UWJXXZWJ TK LFYXGD X JQGTB',
#  '',
#  '',
#  '',
#  'FSI KFQQX  FSI GWJFPX',
#  '',
#  'LFYXGD  HTSY I',
#  'FM    XTWWD',
#  '',
#  'MJ HQZRXNQD YWNJX YT WJUFNW YMJ HQTHP  GZY IWTUX NY FLFNS',
#  '',
#  'SNHP',
#  'NINTYNHFQQD',
#  'NY X FS TQI    HQTHP',
#  '',
#  'IFNXD',
#  'IJXUJWFYJ KTW XRFQQ YFQP',
#  'QTAJQD YMTZLM  F QTAJQD    HQTHP',
#  '',
#  'LFYXGD KNSFQQD RFSFLJX YT XJY YMJ HQTHP GFHP TS YMJ RFSYQJ',
#  '',
#  'LFYXGD YFPJX F XJFY',
#  '',
#  'F QTSL XNQJSY GJFY',
#  '',
#  'IFNXD  HTSY I',
#  'BJ MFAJS Y RJY KTW RFSD DJFWX',
#  '',
#  'LFYXGD',
#  'FS FZYTRFYNH WJKQJC',
#  'KNAJ DJFWX SJCY STAJRGJW',
#  '',
#  'YMJ UWJHNXNTS TK LFYXGD X FSXBJW NX FHZYJQD JRGFWWFXXNSL',
#  '',
#  'SNHP',
#  'FGWZUYQD',
#  'YJF',
#  '',
#  'LFYXGD',
#  'IDNSL',
#  'YMFSP DTZ TQI XUTWY',
#  '',
#  'IFNXD',
#  'FQXT RTWYNKNJI',
#  'IFWQNSL YMFSP DTZ',
#  '',
#  'SNHP UTZWX  FSI YMJD FQQ XNY XYNKKQD  XNUUNSL YMJNW YJF',
#  '',
#  'F QTSL  YJWWNGQJ XNQJSHJ',
#  '',
#  'XZIIJSQD SNHP XYFSIX',
#  '',
#  'SNHP',
#  'N OZXY SJJI YT    UTU NSYT YTBS',
#  '',
#  'LFYXGD',
#  'MTWWNKNJI',
#  'YTBS',
#  '',
#  '',
#  '',
#  'SNHP',
#  'YMJ ANQQFLJ  N QQ GJ WNLMY GFHP',
#  '',
#  'FX SNHP QJFAJX  LFYXGD KTQQTBX',
#  '',
#  'LFYXGD',
#  'N AJ LTY YT XUJFP YT DTZ',
#  '',
#  '',
#  'NSY  SNHP X GZSLFQTB   PNYHMJS   HTSYNSZTZX',
#  '',
#  'BNQIQD KTQQTBNSL SNHP  LFYXGD BMNXUJWX RNXJWFGQD',
#  '',
#  'LFYXGD',
#  'TM  LTI  YMNX NX F RNXYFPJ  F',
#  'YJWWNGQJ  YJWWNGQJ RNXYFPJ',
#  '',
#  'SNHP',
#  'DTZ WJ OZXY JRGFWWFXXJI  YMFY X',
#  'FQQ    IFNXD X JRGFWWFXXJI YTT',
#  '',
#  'LFYXGD',
#  'XMJ X JRGFWWFXXJI',
#  '',
#  'SNHP',
#  'OZXY FX RZHM FX DTZ FWJ',
#  '',
#  'LFYXGD',
#  'ITS Y YFQP XT QTZI',
#  '',
#  'SNHP',
#  'DTZ WJ FHYNSL QNPJ F QNYYQJ GTD',
#  'DTZ WJ WZIJ  IFNXD X NS YMJWJ FQQ',
#  'FQTSJ FSI',
#  '',
#  'LFYXGD WFNXJX MNX MFSI  QTTPX FY SNHP WJUWTFHMKZQQD  FSI',
#  'MJFIX GFHP NSYT YMJ QNANSL WTTR',
#  '',
#  '',
#  'JCY  SNHP X GZSLFQTB   HTSYNSZTZX',
#  '',
#  'SNHP WZSX KTW F YWJJ BMTXJ QJFAJX XMNJQI FLFNSXY YMJ WFNS',
#  '',
#  'SNHP  A T',
#  'QTTPNSL TAJW RD XYTWD XT KFW  N R',
#  'WJRNSIJI YMFY KTW YMJ XJHTSI YNRJ',
#  'YMFY XZRRJW',
#  '',
#  'BNIJ  SNHP GJSJFYM YMJ YWJJ QTTPX YNSD  FSI AJWD FQTSJ',
#  '',
#  'SNHP  A T',
#  'N BFX LZFWINSL TYMJW UJTUQJ X',
#  'XJHWJYX',
#  '',
#  '',
#  '',
#  'NSY  SNHP X GZSLFQTB   QNANSL WTTR   IFD',
#  '',
#  'QFYJW  SNHP WJ JSYJWX  GJIWFLLQJI  WFNS XTFPJI',
#  '',
#  'SNHP  A T',
#  'TSHJ FLFNS N BFX BNYMNS',
#  '',
#  'MJ YWNJX YT LJY LFYXGD FSI IFNXD X FYYJSYNTS  YT ST FAFNQ',
#  'YMJ QTAJWX FWJ HTRUQJYJQD FSI YTYFQQD FGXTWGJI NS JFHM TYMJW',
#  '',
#  'SNHP  A T',
#  'FSI BNYMTZY',
#  '',
#  'SNHP GFSLX UTYX NS YMJ XNSP   XYNQQ STYMNSL',
#  '',
#  'MJ HQJFWX MNX YMWTFY',
#  '',
#  'SNHP',
#  'NYX    XYTUUJI WFNSNSL',
#  '',
#  'IFNXD YZWSX  F WFINFSY XRNQJ  JAJWD AJXYNLJ TK JRGFWWFXXRJSY',
#  'GJYBJJS IFNXD FSI LFYXGD NX LTSJ  LFYXGD QNYJWFQQD LQTBX',
#  '',
#  'LFYXGD',
#  'DJX  NY MFX',
#  'YT IFNXD',
#  'MFXS Y NY',
#  '',
#  'MJ XYFSIX  BFQPX YT YMJ BNSITB FSI QTTPX TZY FHWTXX YMJ GFD',
#  '',
#  'LFYXGD  HTSY I',
#  'BMFY IT DTZ YMNSP TK YMFY  IFNXD',
#  'HTRJ QTTP',
#  '',
#  'IFNXD OTNSX LFYXGD FSI YMJD XYJU TZY TSYT YMJ UTWHM YTLJYMJW',
#  '',
#  '',
#  'JCY  SNHP X GZSLFQTB   UTWHM   HTSYNSZTZX',
#  '',
#  'IFNXD',
#  'QTTP  NYX RD MTZXJ  OZXY YMJWJ',
#  'FHWTXX YMJ GFD',
#  '',
#  'LFYXGD FSI IFNXD X JDJX RJJY',
#  '',
#  'LFYXGD',
#  'N PSTB  N MFAJ YMJ XFRJ ANJB KWTR',
#  'RD UQFHJ',
#  '',
#  'IFNXD',
#  'BMJWJ X DTZW UQFHJ',
#  '',
#  'LFYXGD YZWSX GFHP YT SNHP',
#  '',
#  '',
#  '',
#  'LFYXGD',
#  'SNHP  N BFSY DTZ FSI IFNXD GTYM YT',
#  'XJJ RD MTZXJ  N I QNPJ YT XMTB MJW',
#  'FWTZSI',
#  '',
#  'SNHP',
#  'FWJ DTZ XZWJ DTZ BFSY RJ YT HTRJ',
#  '',
#  'LFYXGD',
#  'FGXTQZYJQD  TQI XUTWY  FGXTQZYJQD',
#  '',
#  '',
#  'JCY  LFYXGD X HFXYQJ   KWTSY LFYJX   IFD',
#  '',
#  'XJWAFSYX XBNSL TUJS NAD HTAJWJI LFYJX',
#  '',
#  'LFYXGD',
#  'UWTZIQD',
#  'N MFI YMJ LFYJX GWTZLMY NS KWTR F',
#  'HFXYQJ NS STWRFSID',
#  '',
#  'WJAJFQ  LFYXGD X HFXYQJ LQNXYJSNSL NS YMJ XZSQNLMY',
#  '',
#  'HQTXJ TS  IFNXD  F IJQNLMYJI HWD',
#  '',
#  'IFNXD',
#  'TM  OFD      NYX XT LWFSI',
#  '',
#  'LFYXGD',
#  'IT DTZ QNPJ NY',
#  '',
#  'IFNXD',
#  'N QTAJ NY     GZY MTB IT DTZ QNAJ',
#  'MJWJ FQQ FQTSJ',
#  '',
#  'LFYXGD',
#  'N ITS Y  N PJJU NY FQBFDX KZQQ TK',
#  'NSYJWJXYNSL  HJQJGWFYJI UJTUQJ',
#  '',
#  'FX IFNXD WZSX FMJFI  LFYXGD RZWRZWX YT SNHP',
#  '',
#  'LFYXGD  HTSY I',
#  'RD MTZXJ QTTPX BJQQ ITJXS Y NY  XJJ',
#  'MTB YMJ BMTQJ KWTSY HFYHMJX YMJ',
#  'QNLMY QNPJ YMFY',
#  '',
#  'IFNXD DJQQX GFHP',
#  '',
#  'IFZXD',
#  'HTRJ TS DTZ YBT  N BFSY YMJ WTDFQ',
#  'YTZW',
#  '',
#  'INXXTQAJ YT',
#  '',
#  '',
#  '',
#  'JCY  LFYXGD X HFXYQJ   LFWIJSX   IFD',
#  '',
#  'LFYXGD MFX YWFSXKTWRJI NSYT F LTTI SFYZWJI XMTB TKK  MZWWDNSL',
#  'SNHP FSI IFNXD YMWTZLM F RFEJ TK KFSYFXYNHFQ LFWIJSX  UFXY',
#  'RFLSNKNHJSY KTZSYFNSX FSI NSYT MNX HFXYQJ',
#  '',
#  '',
#  'NSY  LFYXGD X HFXYQJ   PNYHMJS   IFD',
#  '',
#  'LFYGXD XMTBX TKK MNX GWFSI SJB TWFSLJ OZNHJW',
#  '',
#  'LFYGXD',
#  'DTZ RZXY ZSIJWXYFSI  N QNPJ FQQ',
#  'YMNSLX YMFY FWJ RTIJWS',
#  '',
#  'IFNXD WJFINJX F HTHPYFNQ XMFPJW GJSJFYM YMJ XUTZY TK YMJ',
#  'LNFSY XNQAJW TWFSLJ OZNHJ RFHMNSJ',
#  '',
#  'LFYXGD',
#  'NK DTZ UWJXX YMNX GZYYTS MJWJ  YMJ',
#  'TWFSLJX XMTTY YMWTZLM MJWJ  FWJ',
#  'HWZXMJI YMJWJ    YMJ OZNHJ TK',
#  'TWFSLJX JCYWFHYJI NS TSJ MTZW',
#  '',
#  'LFYXGD UWJXXJX  YMJ RFHMNSJ LWTFSX FSI OZNHJ XUQFXMJX TZY',
#  '',
#  'INXXTQAJ YT',
#  '',
#  '',
#  'JCY  LFYXGD X GJFHM   INANSL UTSYTTS   QFYJ FKYJWSTTS',
#  '',
#  'IFNXD  SNHP FSI LFYXGD IWZSPJSQD IWNAJ LTQK GFQQX TZY YTBFWI',
#  'YMJ GFD  SNHP KNQRX TS YMJ BTWQI X KNWXY MTRJ HFRHTWIJW',
#  '',
#  'LFYXGD',
#  'NYX F WJRFWPFGQJ QNYYQJ HFRJWF',
#  'QFYJXY IJXNLS',
#  '',
#  'BMNQJ  SJFWGD  F GZYQJW NS F GTFY XYFSIX BFYHM TAJW F',
#  'XUNSSNSL LWFRTUMTSJ FSI GTYYQJX TK HMFRUFLSJ',
#  '',
#  'IFNXD',
#  'DTZ IT PSTB  N R F HMFRUNTS LTQKJW',
#  'ITS Y DTZ  MJWJ  N QQ XMTB DTZ MTB',
#  'NYX ITSJ',
#  '',
#  'HWFHP  IFNXD HZYX F RFWAJQTZX XBNSL  XSFUUNSL F HQZG NS YBT',
#  '',
#  'XMJ KFQQX NSYT LFYXGD FWRX',
#  '',
#  'SNHP KNQRX',
#  '',
#  '',
#  '',
#  'LFYXGD',
#  'XMJ QTTPX QNPJ XMJ HTZQI GJ TS YMJ',
#  'HTAJW TK ATLZJ  ITS Y DTZ YMNSP',
#  '',
#  'INXXTQAJ YT',
#  '',
#  '',
#  'NSY  LFYXGD X HFXYQJ   LWFSI GFQQWTTR   JFWQD JAJSNSL',
#  '',
#  'LFYXGD FSI SNHP YWFNQ GJMNSI IFNXD  HWTXXNSL YMJ GFQQWTTR',
#  '',
#  'IFNXD  HMFRUFLSJ NS MFSI  XUTYX YMJ XTFWNSL GFQQWTTR TWLFS',
#  '',
#  'IFNXD',
#  'TM     NYX GJFZYNKZQ',
#  '',
#  'LFYXGD',
#  'NYX F HZXYTR BZWQNYEJW',
#  '',
#  'IFNXD',
#  'HFS FSDTSJ UQFD NY',
#  '',
#  'LFYXGD',
#  'PQNUXUWNSLJW HFS',
#  'YT MNX KTTYRJS',
#  'XTRJTSJ BFPJ JBNSL',
#  '',
#  'IFNXD YBNWQX WTZSI  TAJWOTDJI',
#  '',
#  'IFNXD',
#  'RZXNH  FSI BJ HFS IFSHJ FQQ SNLMY',
#  '',
#  'LFYXGD',
#  'JBNSL X F XDRUMTSNH LJSNZX  MJ HFS',
#  'UQFD FSDYMNSL',
#  '',
#  'IFNXD WZSX ZU YMJ XYFNWX FSI HFQQX ITBS',
#  '',
#  'IFNXD',
#  'YMJS N IJRFSI F HMFWQJXYTS',
#  '',
#  'LFYXGD LFEJX ZU FKYJW IFNXD  FSI HTSKNIJX NS SNHP',
#  '',
#  'LFYXGD',
#  'FX NK NS F IWJFR',
#  'XMJ RFPJX NY QTTP XT XUQJSINI',
#  'ITS Y DTZ YMNSP TQI XUTWY',
#  '',
#  'INXXTQAJ YT',
#  '',
#  '',
#  'NSY  LFYXGD X HFXYQJ  LFYXGD X GJIWTTR   JAJSNSL',
#  '',
#  'SNHP FSI IFNXD KTQQTB LFYXGD NSYT YMJ GJIWTTR',
#  '',
#  '',
#  '',
#  'LFYXGD GTZSIX FMJFI  XYFWYNSL ZU F XUNWFQ XYFNW    MJ YMWTBX',
#  'TUJS F RFXXNAJ HFGNSJY  WJAJFQNSL F UWNXR TK XZNYX  IWJXXNSL',
#  'LTBSX  BFYHMJX FSI YNJX',
#  '',
#  'LFYXGD',
#  'N AJ LTY F RFS NS JSLQFSI BMT GZDX',
#  'RJ HQTYMJX',
#  '',
#  'MJ UQFDKZQQD YTXXJX IFNXD F GTFYJW MFY',
#  '',
#  'LFYXGD  HTSY I',
#  'XTRJYMNSL KTW YMJ QFID',
#  '',
#  'YMJS MJ GJLNSX DFSPNSL ITBS XMNWYX FSI YTXXNSL YMJR TAJW YMJ',
#  'WFNQ YT IFNXD',
#  '',
#  'IFNXD',
#  'N AJ SJAJW XJJS FSDYMNSL QNPJ NY',
#  '',
#  'LFYXGD',
#  'MJ XJSIX TAJW F XJQJHYNTS FY YMJ',
#  'GJLNSSNSL TK JFHM XJFXTS',
#  '',
#  'IFNXD',
#  'OFD',
#  '',
#  'BNYM JAJW NSHWJFXNSL JSYMZXNFXR',
#  '',
#  'LFYXGD',
#  'YMJXJ FWJ XNQP  QNSJS  NSINFS',
#  'KQFSSJQ  JLDUYNFS HTYYTS',
#  '',
#  'IFNXD  NSYTCNHFYJI  QJFUX TS YMJ GJI  FWRX TZYXYWJYHMJI',
#  '',
#  'IFNXD',
#  'ST  OFD    DTZ QQ WZNS YMJR',
#  'YT SNHP',
#  'SNHPD  MJ X F RFIRFS',
#  '',
#  'RTWJ FSI RTWJ FSI RTWJ XMNWYX KQTFY ITBS',
#  '',
#  'YMJ WZRGQJ TK INXYFSY YMZSIJW',
#  '',
#  'HQTXJ TS  IFNXD  YNRJ XQTBX FX XMNWYX KQZYYJW  QNPJ LNFSY',
#  'XSTBKQFPJX  ITBS YTBFWI MJW  XQTBQD  VZNJYQD  MJW RNWYM',
#  'YWFSXKTWRX YT XTGX    XMJ MNIJX MJW KFHJ NS XMNWYX',
#  '',
#  'LFYXGD JFXJX ITBS YMJ XYFNWX FSI SJXYQJX GJXNIJ IFNXD  YFPNSL',
#  'MJW YJFW XYWJFPJI KFHJ NS MNX MFSIX',
#  '',
#  'LFYXGD',
#  'BMFY NX NY',
#  '',
#  '',
#  '',
#  'IFNXD',
#  'NY X OZXY    NY RFPJX RJ XFI',
#  'GJHFZXJ',
#  '',
#  'IFNXD LQFSHJX NS SNHP X INWJHYNTS',
#  '',
#  'LFYXGD',
#  'BMD',
#  '',
#  'IFNXD',
#  'GJHFZXJ',
#  '',
#  'F XZXUJSIJI RTRJSY  IFNXD NX NSHFUFGQJ TK XUJFPNSL MJW MJFWY',
#  '',
#  'SNHP  A T',
#  'KNAJ QTXY DJFWX XYWZLLQJI TS',
#  'IFNXD X QNUX  GZY FQQ XMJ HTZQI',
#  'RFSFLJ BFX',
#  '',
#  'IFNXD',
#  'NY X OZXY    GJHFZXJ N AJ SJAJW',
#  'XJJS XZHM GJFZYNKZQ XMNWYX GJKTWJ',
#  '',
#  'LFYXGD',
#  'NK NY BFXS Y KTW YMJ RNXY BJ HTZQI',
#  'XJJ YMJ LWJJS QNLMY',
#  '',
#  'IFNXD',
#  'BMFY LWJJS QNLMY',
#  '',
#  'LFYXGD',
#  'YMJ TSJ YMFY GZWSX FQQ SNLMY FY YMJ',
#  'JSI TK DTZW ITHP',
#  '',
#  'FX LFYXGD FSI IFNXD XYFWJ TZY FHWTXX YMJ GFD',
#  '',
#  'SNHP  A T',
#  'UTXXNGQD  NY MFI THHZWWJI YT LFYXGD',
#  'YMFY YMJ HTQTXXFQ XNLSNKNHFSHJ TK',
#  'YMFY QNLMY MFI AFSNXMJI KTWJAJW',
#  'STB  NY BFX TSHJ FLFNS OZXY F LWJJS',
#  'QNLMY TS F ITHP  MNX HTZSY TK',
#  'JSHMFSYJI TGOJHYX MFI INRNSNXMJI GD',
#  'TSJ',
#  '',
#  'SNHP  NRUJQQJI YT WJRNSI IFNXD FSI LFYXGD TK MNX UWJXJSHJ',
#  'JRJWLJX KWTR YMJ XMFITBX FSI IJXHJSIX YMJ XUNWFQ XYFNWHFXJ',
#  '',
#  'MJ MTQIX F UMTYT TK FS JQIJWQD RFS NS DFHMYNSL HTXYZRJ',
#  '',
#  'SNHP',
#  'BMT X YMNX  DTZW KFYMJW',
#  '',
#  '',
#  '',
#  'LFYXGD',
#  'ST  ST   YMFY X RW  IFS HTID  TQI',
#  'XUTWY    MJ X IJFI STB  MJ ZXJI YT',
#  'GJ RD GJXY KWNJSI DJFWX FLT',
#  '',
#  'IFNXD OTNSX SNHP FY YMJ GTYYTR TK YMJ XYJUX  NS YMJ UMTYT',
#  'BNYM HTID  FQXT NS DFHMYNSL HTXYZRJ  NX F DTZSL LFYXGD',
#  '',
#  'IFNXD',
#  'YJFXJX',
#  'DTZ SJAJW YTQI RJ DTZ MFI F',
#  'UTRUFITZW    TW F DFHMY',
#  '',
#  'LFYXGD MFXYNQD UQZHPX F XHWFUGTTP KWTR F WTB TS MNX IJXP',
#  '',
#  'LFYXGD',
#  'N BFSY YT XMTB DTZ XTRJYMNSL',
#  'QTTP  MJWJ X F QTY TK HQNUUNSLX',
#  'FGTZY DTZ',
#  '',
#  'YMJD FIRNWJ F XHWFUGTTP YTLJYMJW',
#  '',
#  'IFNXD',
#  'YTZHMJI',
#  'DTZ XFAJI RD QJYYJWX',
#  '',
#  'LFYXGD',
#  'YMNX BFX RD KNWXY UMTYT TK DTZ',
#  '',
#  'FX IFNXD KQNUX YMWTZLM FSI UZQQX TZY FS TQI QJYYJW TK MJWX',
#  'BJ MJFW MJW WJFINSL YMJ QJYYJW NS FGXYWFHY ATNHJTAJW',
#  '',
#  'IFNXD  A T',
#  'BJ HFSY QTXJ JFHM TYMJW FSI QJY FQQ',
#  'YMNX LQTWNTZX QTAJ JSI NS STYMNSL',
#  'HTRJ MTRJ  N QQ GJ MJWJ BFNYNSL FSI',
#  'MTUNSL  KTW JAJWD QTSL IWJFR TK DTZ',
#  'YT HTRJ YWZJ    HTRJ MTRJ OFD',
#  '',
#  'GGGWWWSSSLLL  YMJ UMTSJ XMWNQQX',
#  '',
#  'LFYXGD',
#  'JCHZXJ RJ',
#  '',
#  'LFYXGD HWTXXJX YMJ WTTR  XSFYHMJX ZU YMJ WJHJNAJW  FSI YZWSX',
#  'FBFD    MJ QTBJWX MNX ATNHJ',
#  '',
#  'LFYXGD  NSYT UMTSJ   HTSY I',
#  'BJQQ N HFS Y YFQP STB TQI XUTWY',
#  '',
#  'FX YMJ YNRGWJ TK LFYXGD X ATNHJ IFWPJSX BJ UZXM HQTXJW',
#  '',
#  'LFYXGD  NSYT UMTSJ   HTSY I',
#  'N XFNI F XRFQQ YTBS',
#  '',
#  '',
#  '',
#  'JHZ  LFYXGD X JDJX SFWWTB',
#  '',
#  'LFYXGD  NSYT UMTSJ   HTSY I',
#  'MJ RZXY PSTB BMFY F XRFQQ YTBS NX',
#  '',
#  'GTTTTRRR  F XYTWRNSL BNSI GFSLX TUJS YMJ KWJSHM BNSITBX',
#  '',
#  'FX SNHP RTAJX YT XMZY YMJR  MJ LQNRUXJX LFYXGD',
#  '',
#  'LFYXGD  NSYT UMTSJ   HTSY I',
#  'KWNLMYJSNSL',
#  'BJQQ  MJ X ST ZXJ YT ZX NK IJYWTNY',
#  'NX MNX NIJF TK F XRFQQ YTBS',
#  '',
#  'LFYXGD WNSLX TKK FGWZUYQD  FSI HFYHMJX SNHP X JDJ   F YJSXJ',
#  ...]

# %% [markdown]
# ---

# %% [markdown]
# ### Word and character count

# %%
words3 = cleaned.flatMap(
    lambda line: line.split()
)

chars3 = cleaned.flatMap(
    lambda line: list(line)
)

# %%
num3words = words3.count()
num3words
# Out:
# 4565

# %%
num3chars = chars3.count()
num3chars
# Out:
# 23839

# %% [markdown]
# ---

# %% [markdown]
# ### Frequency of the words in the document

# %%
words3freq = words3\
    .map(lambda word: (word, 1))\
        .reduceByKey(lambda num_word1, num_word2: num_word1+num_word2)\
            .map(lambda word: (word[0], word[1], word[1]/float(num3words)))\
                .sortBy(lambda x: x[1], ascending=False)

# %%
words3freq.collect()
# Out:
# [('LFYXGD', 198, 0.043373493975903614),
#  ('YMJ', 167, 0.03658269441401971),
#  ('SNHP', 139, 0.03044906900328587),
#  ('F', 127, 0.027820372398685653),
#  ('YT', 115, 0.025191675794085433),
#  ('X', 114, 0.02497261774370208),
#  ('IFNXD', 102, 0.02234392113910186),
#  ('FSI', 88, 0.01927710843373494),
#  ('N', 75, 0.01642935377875137),
#  ('TK', 70, 0.01533406352683461),
#  ('DTZ', 67, 0.014676889375684557),
#  ('MJ', 57, 0.01248630887185104),
#  ('NS', 54, 0.011829134720700987),
#  ('NY', 47, 0.010295728368017525),
#  ('MNX', 37, 0.008105147864184009),
#  ('Y', 31, 0.006790799561883899),
#  ('FX', 30, 0.0065717415115005475),
#  ('T', 30, 0.0065717415115005475),
#  ('TS', 28, 0.006133625410733845),
#  ('NX', 26, 0.005695509309967141),
#  ('I', 26, 0.005695509309967141),
#  ('A', 26, 0.005695509309967141),
#  ('FY', 24, 0.005257393209200438),
#  ('INXXTQAJ', 23, 0.005038335158817087),
#  ('YMFY', 23, 0.005038335158817087),
#  ('BNYM', 22, 0.004819277108433735),
#  ('KTW', 21, 0.004600219058050383),
#  ('IFD', 21, 0.004600219058050383),
#  ('JCY', 20, 0.004381161007667032),
#  ('BFX', 20, 0.004381161007667032),
#  ('NSYT', 20, 0.004381161007667032),
#  ('FQQ', 19, 0.00416210295728368),
#  ('BJ', 18, 0.003943044906900329),
#  ('HTSY', 18, 0.003943044906900329),
#  ('NSY', 18, 0.003943044906900329),
#  ('TQI', 17, 0.003723986856516977),
#  ('MJW', 17, 0.003723986856516977),
#  ('HFXYQJ', 16, 0.0035049288061336256),
#  ('HTID', 16, 0.0035049288061336256),
#  ('XMJ', 16, 0.0035049288061336256),
#  ('YTR', 16, 0.0035049288061336256),
#  ('OZXY', 16, 0.0035049288061336256),
#  ('SNLMY', 15, 0.0032858707557502738),
#  ('GZSLFQTB', 15, 0.0032858707557502738),
#  ('YMNX', 15, 0.0032858707557502738),
#  ('RD', 15, 0.0032858707557502738),
#  ('QTTPX', 15, 0.0032858707557502738),
#  ('RJ', 14, 0.0030668127053669223),
#  ('GJ', 14, 0.0030668127053669223),
#  ('DTZSL', 14, 0.0030668127053669223),
#  ('TSJ', 14, 0.0030668127053669223),
#  ('FS', 14, 0.0030668127053669223),
#  ('OTWIFS', 13, 0.0028477546549835705),
#  ('ITS', 13, 0.0028477546549835705),
#  ('YZWSX', 13, 0.0028477546549835705),
#  ('TZY', 13, 0.0028477546549835705),
#  ('OFD', 13, 0.0028477546549835705),
#  ('GZY', 12, 0.002628696604600219),
#  ('BMFY', 12, 0.002628696604600219),
#  ('ST', 11, 0.0024096385542168677),
#  ('XUTWY', 11, 0.0024096385542168677),
#  ('GFHP', 11, 0.0024096385542168677),
#  ('DFHMY', 11, 0.0024096385542168677),
#  ('FWJ', 11, 0.0024096385542168677),
#  ('QNPJ', 11, 0.0024096385542168677),
#  ('AJ', 11, 0.0024096385542168677),
#  ('WTTR', 11, 0.0024096385542168677),
#  ('NYX', 10, 0.002190580503833516),
#  ('MFI', 10, 0.002190580503833516),
#  ('YMNSP', 10, 0.002190580503833516),
#  ('HFS', 10, 0.002190580503833516),
#  ('KWTR', 10, 0.002190580503833516),
#  ('YMJWJ', 10, 0.002190580503833516),
#  ('XJJ', 9, 0.0019715224534501644),
#  ('NK', 9, 0.0019715224534501644),
#  ('BFSY', 9, 0.0019715224534501644),
#  ('YTBFWI', 9, 0.0019715224534501644),
#  ('MJWJ', 9, 0.0019715224534501644),
#  ('FHWTXX', 8, 0.0017524644030668128),
#  ('ZU', 8, 0.0017524644030668128),
#  ('HTRJ', 8, 0.0017524644030668128),
#  ('HQTHP', 8, 0.0017524644030668128),
#  ('XT', 8, 0.0017524644030668128),
#  ('DJFWX', 8, 0.0017524644030668128),
#  ('IT', 8, 0.0017524644030668128),
#  ('TM', 8, 0.0017524644030668128),
#  ('MNR', 7, 0.0015334063526834612),
#  ('DTZW', 7, 0.0015334063526834612),
#  ('STY', 7, 0.0015334063526834612),
#  ('R', 7, 0.0015334063526834612),
#  ('YMJD', 7, 0.0015334063526834612),
#  ('QFBS', 7, 0.0015334063526834612),
#  ('QNANSL', 7, 0.0015334063526834612),
#  ('PSTB', 7, 0.0015334063526834612),
#  ('RTWJ', 7, 0.0015334063526834612),
#  ('KWTSY', 7, 0.0015334063526834612),
#  ('STB', 7, 0.0015334063526834612),
#  ('HTSYNSZTZX', 7, 0.0015334063526834612),
#  ('TAJW', 7, 0.0015334063526834612),
#  ('HQTXJ', 7, 0.0015334063526834612),
#  ('QNLMY', 7, 0.0015334063526834612),
#  ('YMWTZLM', 7, 0.0015334063526834612),
#  ('BJQQ', 7, 0.0015334063526834612),
#  ('QTTP', 7, 0.0015334063526834612),
#  ('RTSJD', 7, 0.0015334063526834612),
#  ('YMJR', 6, 0.0013143483023001095),
#  ('LTY', 6, 0.0013143483023001095),
#  ('GD', 6, 0.0013143483023001095),
#  ('GFD', 6, 0.0013143483023001095),
#  ('MFAJ', 6, 0.0013143483023001095),
#  ('YJF', 6, 0.0013143483023001095),
#  ('ITTW', 6, 0.0013143483023001095),
#  ('BMJWJ', 6, 0.0013143483023001095),
#  ('QTSL', 6, 0.0013143483023001095),
#  ('QQ', 6, 0.0013143483023001095),
#  ('TYMJW', 6, 0.0013143483023001095),
#  ('FWTZSI', 6, 0.0013143483023001095),
#  ('UZXM', 6, 0.0013143483023001095),
#  ('XYFSIX', 6, 0.0013143483023001095),
#  ('ITBS', 6, 0.0013143483023001095),
#  ('QFYJ', 6, 0.0013143483023001095),
#  ('KNAJ', 6, 0.0013143483023001095),
#  ('WNLMY', 6, 0.0013143483023001095),
#  ('GFQQWTTR', 6, 0.0013143483023001095),
#  ('FKYJWSTTS', 5, 0.001095290251916758),
#  ('XJJS', 5, 0.001095290251916758),
#  ('QTAJ', 5, 0.001095290251916758),
#  ('FBFD', 5, 0.001095290251916758),
#  ('YFCN', 5, 0.001095290251916758),
#  ('LWFXX', 5, 0.001095290251916758),
#  ('HZY', 5, 0.001095290251916758),
#  ('QNYYQJ', 5, 0.001095290251916758),
#  ('WJ', 5, 0.001095290251916758),
#  ('KFHJ', 5, 0.001095290251916758),
#  ('LWJJS', 5, 0.001095290251916758),
#  ('UMTSJ', 5, 0.001095290251916758),
#  ('LFYE', 5, 0.001095290251916758),
#  ('XJSFYTW', 5, 0.001095290251916758),
#  ('GJKTWJ', 5, 0.001095290251916758),
#  ('GZHMFSFS', 5, 0.001095290251916758),
#  ('SJAJW', 5, 0.001095290251916758),
#  ('MTZXJ', 5, 0.001095290251916758),
#  ('FGTZY', 5, 0.001095290251916758),
#  ('FGXTQZYJQD', 5, 0.001095290251916758),
#  ('YTT', 5, 0.001095290251916758),
#  ('RZXY', 5, 0.001095290251916758),
#  ('XZNY', 5, 0.001095290251916758),
#  ('KFQQX', 5, 0.001095290251916758),
#  ('RTRJSY', 5, 0.001095290251916758),
#  ('FLFNS', 5, 0.001095290251916758),
#  ('TKK', 5, 0.001095290251916758),
#  ('YTBS', 5, 0.001095290251916758),
#  ('XMTB', 5, 0.001095290251916758),
#  ('LWFSI', 5, 0.001095290251916758),
#  ('HTZQI', 5, 0.001095290251916758),
#  ('XMNWYX', 5, 0.001095290251916758),
#  ('JSI', 5, 0.001095290251916758),
#  ('RFS', 4, 0.0008762322015334064),
#  ('JDJX', 4, 0.0008762322015334064),
#  ('FSTYMJW', 4, 0.0008762322015334064),
#  ('TW', 4, 0.0008762322015334064),
#  ('FM', 4, 0.0008762322015334064),
#  ('GJJS', 4, 0.0008762322015334064),
#  ('QNKJ', 4, 0.0008762322015334064),
#  ('WFNS', 4, 0.0008762322015334064),
#  ('XJWAFSYX', 4, 0.0008762322015334064),
#  ('XNQJSHJ', 4, 0.0008762322015334064),
#  ('XNYX', 4, 0.0008762322015334064),
#  ('KNSFQQD', 4, 0.0008762322015334064),
#  ('INI', 4, 0.0008762322015334064),
#  ('KFW', 4, 0.0008762322015334064),
#  ('YMJS', 4, 0.0008762322015334064),
#  ('YMJNW', 4, 0.0008762322015334064),
#  ('AJWD', 4, 0.0008762322015334064),
#  ('UJTUQJ', 4, 0.0008762322015334064),
#  ('RJJY', 4, 0.0008762322015334064),
#  ('LFYGXD', 4, 0.0008762322015334064),
#  ('IFSHJ', 4, 0.0008762322015334064),
#  ('XYFNWX', 4, 0.0008762322015334064),
#  ('IFS', 4, 0.0008762322015334064),
#  ('QTY', 4, 0.0008762322015334064),
#  ('ATNHJ', 4, 0.0008762322015334064),
#  ('LZQNHP', 4, 0.0008762322015334064),
#  ('QJYYJW', 4, 0.0008762322015334064),
#  ('FKYJW', 4, 0.0008762322015334064),
#  ('KNWXY', 4, 0.0008762322015334064),
#  ('UZQQX', 4, 0.0008762322015334064),
#  ('MTRJ', 4, 0.0008762322015334064),
#  ('LT', 4, 0.0008762322015334064),
#  ('RZHM', 4, 0.0008762322015334064),
#  ('KFATW', 4, 0.0008762322015334064),
#  ('JRGFWWFXXJI', 4, 0.0008762322015334064),
#  ('SJB', 4, 0.0008762322015334064),
#  ('JAJWDYMNSL', 4, 0.0008762322015334064),
#  ('FQTSJ', 4, 0.0008762322015334064),
#  ('JFHM', 4, 0.0008762322015334064),
#  ('XRFQQ', 4, 0.0008762322015334064),
#  ('YFQP', 4, 0.0008762322015334064),
#  ('MTB', 4, 0.0008762322015334064),
#  ('RW', 4, 0.0008762322015334064),
#  ('GJSJFYM', 3, 0.0006571741511500548),
#  ('LNWQ', 3, 0.0006571741511500548),
#  ('UFWYNJX', 3, 0.0006571741511500548),
#  ('BMT', 3, 0.0006571741511500548),
#  ('YFPJX', 3, 0.0006571741511500548),
#  ('YNRJ', 3, 0.0006571741511500548),
#  ('MNRXJQK', 3, 0.0006571741511500548),
#  ('ITJXS', 3, 0.0006571741511500548),
#  ('JAJSNSL', 3, 0.0006571741511500548),
#  ('NXQFSI', 3, 0.0006571741511500548),
#  ('INWY', 3, 0.0006571741511500548),
#  ('UFXY', 3, 0.0006571741511500548),
#  ('UQFHJ', 3, 0.0006571741511500548),
#  ('BTWQI', 3, 0.0006571741511500548),
#  ('FQWNLMY', 3, 0.0006571741511500548),
#  ('FSD', 3, 0.0006571741511500548),
#  ('BTZQI', 3, 0.0006571741511500548),
#  ('RNLMY', 3, 0.0006571741511500548),
#  ('ITSJ', 3, 0.0006571741511500548),
#  ('KQTBJWX', 3, 0.0006571741511500548),
#  ('MTQIX', 3, 0.0006571741511500548),
#  ('BFYHMJX', 3, 0.0006571741511500548),
#  ('BNSITB', 3, 0.0006571741511500548),
#  ('UTWHM', 3, 0.0006571741511500548),
#  ('RFSYJQUNJHJ', 3, 0.0006571741511500548),
#  ('GJFZYNKZQ', 3, 0.0006571741511500548),
#  ('RZWRZW', 3, 0.0006571741511500548),
#  ('JSYJWX', 3, 0.0006571741511500548),
#  ('RFSFLJX', 3, 0.0006571741511500548),
#  ('XUJFP', 3, 0.0006571741511500548),
#  ('YJSXNTS', 3, 0.0006571741511500548),
#  ('RJY', 3, 0.0006571741511500548),
#  ('QTAJQD', 3, 0.0006571741511500548),
#  ('YJWWNGQJ', 3, 0.0006571741511500548),
#  ('GTD', 3, 0.0006571741511500548),
#  ('MFSI', 3, 0.0006571741511500548),
#  ('WZSX', 3, 0.0006571741511500548),
#  ('TSHJ', 3, 0.0006571741511500548),
#  ('LFYJX', 3, 0.0006571741511500548),
#  ('TUJS', 3, 0.0006571741511500548),
#  ('OZNHJ', 3, 0.0006571741511500548),
#  ('HFQQX', 3, 0.0006571741511500548),
#  ('YMJXJ', 3, 0.0006571741511500548),
#  ('XQTBQD', 3, 0.0006571741511500548),
#  ('GJHFZXJ', 3, 0.0006571741511500548),
#  ('UMTYT', 3, 0.0006571741511500548),
#  ('FLT', 3, 0.0006571741511500548),
#  ('BNSI', 3, 0.0006571741511500548),
#  ('XYTWR', 3, 0.0006571741511500548),
#  ('IWZSP', 3, 0.0006571741511500548),
#  ('STWYM', 3, 0.0006571741511500548),
#  ('UTQT', 3, 0.0006571741511500548),
#  ('UQFDJW', 3, 0.0006571741511500548),
#  ('RFWWNJI', 3, 0.0006571741511500548),
#  ('JAJW', 3, 0.0006571741511500548),
#  ('HFW', 3, 0.0006571741511500548),
#  ('YMTZLMY', 3, 0.0006571741511500548),
#  ('YTLJYMJW', 3, 0.0006571741511500548),
#  ('BMJS', 3, 0.0006571741511500548),
#  ('BFXS', 3, 0.0006571741511500548),
#  ('XZRRJW', 3, 0.0006571741511500548),
#  ('WJFQQD', 3, 0.0006571741511500548),
#  ('WFYMJW', 3, 0.0006571741511500548),
#  ('MFSIX', 3, 0.0006571741511500548),
#  ('MFX', 3, 0.0006571741511500548),
#  ('KWJXM', 3, 0.0006571741511500548),
#  ('GFSI', 3, 0.0006571741511500548),
#  ('BNYMTZY', 3, 0.0006571741511500548),
#  ('XZIIJSQD', 3, 0.0006571741511500548),
#  ('YBT', 3, 0.0006571741511500548),
#  ('LQNRUXJX', 3, 0.0006571741511500548),
#  ('XRNQJ', 3, 0.0006571741511500548),
#  ('FMJFI', 3, 0.0006571741511500548),
#  ('IJQNLMYJI', 3, 0.0006571741511500548),
#  ('INXHTAJW', 3, 0.0006571741511500548),
#  ('TSYT', 3, 0.0006571741511500548),
#  ('FQBFDX', 3, 0.0006571741511500548),
#  ('HFRJWF', 3, 0.0006571741511500548),
#  ('UQFD', 3, 0.0006571741511500548),
#  ('GJIWTTR', 3, 0.0006571741511500548),
#  ('IJXP', 3, 0.0006571741511500548),
#  ('IZXP', 3, 0.0006571741511500548),
#  ('IFPTYF', 3, 0.0006571741511500548),
#  ('INXFUUJFWX', 2, 0.0004381161007667032),
#  ('HTRUQJYJQD', 2, 0.0004381161007667032),
#  ('WJFI', 2, 0.0004381161007667032),
#  ('QNSJ', 2, 0.0004381161007667032),
#  ('QTZNXANQQJ', 2, 0.0004381161007667032),
#  ('SJBQD', 2, 0.0004381161007667032),
#  ('YNRJX', 2, 0.0004381161007667032),
#  ('XVZFWJ', 2, 0.0004381161007667032),
#  ('XFB', 2, 0.0004381161007667032),
#  ('XFSYF', 2, 0.0004381161007667032),
#  ('UFUJWX', 2, 0.0004381161007667032),
#  ('BFNYNSL', 2, 0.0004381161007667032),
#  ('XZIIJS', 2, 0.0004381161007667032),
#  ('SJFW', 2, 0.0004381161007667032),
#  ('MTUNSL', 2, 0.0004381161007667032),
#  ('XJJNSL', 2, 0.0004381161007667032),
#  ('MFXS', 2, 0.0004381161007667032),
#  ('GWJFYM', 2, 0.0004381161007667032),
#  ('TUJSX', 2, 0.0004381161007667032),
#  ('ITJX', 2, 0.0004381161007667032),
#  ('NSANYJ', 2, 0.0004381161007667032),
#  ('XMNWY', 2, 0.0004381161007667032),
#  ('BNQI', 2, 0.0004381161007667032),
#  ('FUUJFWX', 2, 0.0004381161007667032),
#  ('MFAJS', 2, 0.0004381161007667032),
#  ('GJI', 2, 0.0004381161007667032),
#  ('UZY', 2, 0.0004381161007667032),
#  ('LJY', 2, 0.0004381161007667032),
#  ('XMFWU', 2, 0.0004381161007667032),
#  ('YMNSL', 2, 0.0004381161007667032),
#  ('ZSIJWXYFSI', 2, 0.0004381161007667032),
#  ('KZQQ', 2, 0.0004381161007667032),
#  ('DJX', 2, 0.0004381161007667032),
#  ('WJAJFQ', 2, 0.0004381161007667032),
#  ('KTQQTBNSL', 2, 0.0004381161007667032),
#  ('XNQAJW', 2, 0.0004381161007667032),
#  ('LTQI', 2, 0.0004381161007667032),
#  ('JCYWFAFLFSY', 2, 0.0004381161007667032),
#  ('FWWFSLJRJSYX', 2, 0.0004381161007667032),
#  ('BFYHMNSL', 2, 0.0004381161007667032),
#  ('UJWMFUX', 2, 0.0004381161007667032),
#  ('BFYHM', 2, 0.0004381161007667032),
#  ('WTQQX', 2, 0.0004381161007667032),
#  ('KQZXMJI', 2, 0.0004381161007667032),
#  ('HMFZKKJZW', 2, 0.0004381161007667032),
#  ('IWNAJ', 2, 0.0004381161007667032),
#  ('QNAJ', 2, 0.0004381161007667032),
#  ('SFRJ', 2, 0.0004381161007667032),
#  ('GJQNJAJ', 2, 0.0004381161007667032),
#  ('KZSSD', 2, 0.0004381161007667032),
#  ('PSTHP', 2, 0.0004381161007667032),
#  ('XTRJTSJ', 2, 0.0004381161007667032),
#  ('XTFPJI', 2, 0.0004381161007667032),
#  ('XYNQQ', 2, 0.0004381161007667032),
#  ('QTAJWX', 2, 0.0004381161007667032),
#  ('XYFSI', 2, 0.0004381161007667032),
#  ('XYFWNSL', 2, 0.0004381161007667032),
#  ('GWJFPX', 2, 0.0004381161007667032),
#  ('JQGTB', 2, 0.0004381161007667032),
#  ('YMFSP', 2, 0.0004381161007667032),
#  ('XNY', 2, 0.0004381161007667032),
#  ('PNYHMJS', 2, 0.0004381161007667032),
#  ('BMNXUJWX', 2, 0.0004381161007667032),
#  ('LTI', 2, 0.0004381161007667032),
#  ('RNXYFPJ', 2, 0.0004381161007667032),
#  ('YWJJ', 2, 0.0004381161007667032),
#  ('QTTPNSL', 2, 0.0004381161007667032),
#  ('BNIJ', 2, 0.0004381161007667032),
#  ('GFSLX', 2, 0.0004381161007667032),
#  ('STYMNSL', 2, 0.0004381161007667032),
#  ('OTNSX', 2, 0.0004381161007667032),
#  ('XBNSL', 2, 0.0004381161007667032),
#  ('HFYHMJX', 2, 0.0004381161007667032),
#  ('LFWIJSX', 2, 0.0004381161007667032),
#  ('TWFSLJ', 2, 0.0004381161007667032),
#  ('YMNSLX', 2, 0.0004381161007667032),
#  ('RFHMNSJ', 2, 0.0004381161007667032),
#  ('BMNQJ', 2, 0.0004381161007667032),
#  ('HMFRUFLSJ', 2, 0.0004381161007667032),
#  ('FWRX', 2, 0.0004381161007667032),
#  ('TWLFS', 2, 0.0004381161007667032),
#  ('FSDYMNSL', 2, 0.0004381161007667032),
#  ('HMFWQJXYTS', 2, 0.0004381161007667032),
#  ('IWJFR', 2, 0.0004381161007667032),
#  ('YFPNSL', 2, 0.0004381161007667032),
#  ('ITHP', 2, 0.0004381161007667032),
#  ('HTXYZRJ', 2, 0.0004381161007667032),
#  ('YTQI', 2, 0.0004381161007667032),
#  ('WTB', 2, 0.0004381161007667032),
#  ('MJFW', 2, 0.0004381161007667032),
#  ('KQTTW', 2, 0.0004381161007667032),
#  ('NRFLJX', 2, 0.0004381161007667032),
#  ('XFSNYFWNZR', 2, 0.0004381161007667032),
#  ('BNSYJW', 2, 0.0004381161007667032),
#  ('BWNYNSL', 2, 0.0004381161007667032),
#  ('MZY', 2, 0.0004381161007667032),
#  ('UTTW', 2, 0.0004381161007667032),
#  ('DJFW', 2, 0.0004381161007667032),
#  ('XZUJWNTW', 2, 0.0004381161007667032),
#  ('FWR', 2, 0.0004381161007667032),
#  ('XFNQJI', 2, 0.0004381161007667032),
#  ('LJSYQJRFS', 2, 0.0004381161007667032),
#  ('SJBXUFUJW', 2, 0.0004381161007667032),
#  ('DTWP', 2, 0.0004381161007667032),
#  ('BFQQ', 2, 0.0004381161007667032),
#  ('LQNYYJWNSL', 2, 0.0004381161007667032),
#  ('GZXNSJXXRFS', 2, 0.0004381161007667032),
#  ('RFD', 2, 0.0004381161007667032),
#  ('RTTS', 2, 0.0004381161007667032),
#  ('BTZQIS', 2, 0.0004381161007667032),
#  ('YJQQ', 2, 0.0004381161007667032),
#  ('XYJUX', 2, 0.0004381161007667032),
#  ('XTFWNSL', 2, 0.0004381161007667032),
#  ('GFWGFWF', 2, 0.0004381161007667032),
#  ('QFYJW', 2, 0.0004381161007667032),
#  ('HFG', 2, 0.0004381161007667032),
#  ('XYWFSLJ', 2, 0.0004381161007667032),
#  ('HTNSHNIJSHJ', 2, 0.0004381161007667032),
#  ('WTZSI', 2, 0.0004381161007667032),
#  ('PSJB', 2, 0.0004381161007667032),
#  ('XMTZQI', 2, 0.0004381161007667032),
#  ('YTWS', 2, 0.0004381161007667032),
#  ('BTRFS', 2, 0.0004381161007667032),
#  ('UFWYD', 2, 0.0004381161007667032),
#  ('LWTFSX', 2, 0.0004381161007667032),
#  ('HTSJD', 2, 0.0004381161007667032),
#  ('QJY', 2, 0.0004381161007667032),
#  ('YFPJ', 2, 0.0004381161007667032),
#  ('ZXJ', 2, 0.0004381161007667032),
#  ('MFUUD', 2, 0.0004381161007667032),
#  ('HFQQ', 2, 0.0004381161007667032),
#  ('YWTZGQJ', 2, 0.0004381161007667032),
#  ('YTRTWWTB', 2, 0.0004381161007667032),
#  ('GTYM', 2, 0.0004381161007667032),
#  ('GJLNSX', 2, 0.0004381161007667032),
#  ('RFPJ', 2, 0.0004381161007667032),
#  ('GZXNSJXX', 2, 0.0004381161007667032),
#  ('XTWY', 2, 0.0004381161007667032),
#  ('YNSD', 2, 0.0004381161007667032),
#  ('LTTISNLMY', 2, 0.0004381161007667032),
#  ('ZSPJRUY', 2, 0.0004381161007667032),
#  ('XRNQJX', 2, 0.0004381161007667032),
#  ('YTU', 2, 0.0004381161007667032),
#  ('KWFRJ', 2, 0.0004381161007667032),
#  ('LFWIJS', 2, 0.0004381161007667032),
#  ('KQFSSJQ', 2, 0.0004381161007667032),
#  ('QJFIX', 2, 0.0004381161007667032),
#  ('ZRGWJQQF', 2, 0.0004381161007667032),
#  ('KQTWFQ', 2, 0.0004381161007667032),
#  ('XFNI', 2, 0.0004381161007667032),
#  ('KTZW', 2, 0.0004381161007667032),
#  ('GJFY', 2, 0.0004381161007667032),
#  ('KNSJ', 2, 0.0004381161007667032),
#  ('YJSXJ', 2, 0.0004381161007667032),
#  ('XYWJYHMJX', 2, 0.0004381161007667032),
#  ('SJJI', 2, 0.0004381161007667032),
#  ('QJFUX', 2, 0.0004381161007667032),
#  ('MJFIX', 2, 0.0004381161007667032),
#  ('RNSI', 2, 0.0004381161007667032),
#  ('BMD', 2, 0.0004381161007667032),
#  ('HFWWFBFD', 2, 0.0004381161007667032),
#  ('MTZW', 2, 0.0004381161007667032),
#  ('KJWINJ', 2, 0.0004381161007667032),
#  ('MFQQ', 2, 0.0004381161007667032),
#  ('RNXJWFGQD', 2, 0.0004381161007667032),
#  ('HJWYFNSQD', 2, 0.0004381161007667032),
#  ('LQFI', 2, 0.0004381161007667032),
#  ('QNUX', 2, 0.0004381161007667032),
#  ('FLFNSXY', 2, 0.0004381161007667032),
#  ('TSQD', 2, 0.0004381161007667032),
#  ('YWNJX', 2, 0.0004381161007667032),
#  ('YMTZLM', 2, 0.0004381161007667032),
#  ('XNQJSY', 2, 0.0004381161007667032),
#  ('FGWZUYQD', 2, 0.0004381161007667032),
#  ('FQXT', 2, 0.0004381161007667032),
#  ('QJFAJX', 2, 0.0004381161007667032),
#  ('JAJWD', 2, 0.0004381161007667032),
#  ('XFRJ', 2, 0.0004381161007667032),
#  ('YWFSXKTWRJI', 2, 0.0004381161007667032),
#  ('RFLSNKNHJSY', 2, 0.0004381161007667032),
#  ('LNFSY', 2, 0.0004381161007667032),
#  ('TWFSLJX', 2, 0.0004381161007667032),
#  ('KNQRX', 2, 0.0004381161007667032),
#  ('GTFY', 2, 0.0004381161007667032),
#  ('PQNUXUWNSLJW', 2, 0.0004381161007667032),
#  ('JBNSL', 2, 0.0004381161007667032),
#  ('RFPJX', 2, 0.0004381161007667032),
#  ('XUNWFQ', 2, 0.0004381161007667032),
#  ('XTRJYMNSL', 2, 0.0004381161007667032),
#  ('QFID', 2, 0.0004381161007667032),
#  ('INXYFSY', 2, 0.0004381161007667032),
#  ('DFHMYNSL', 2, 0.0004381161007667032),
#  ('IJFI', 2, 0.0004381161007667032),
#  ('XHWFUGTTP', 2, 0.0004381161007667032),
#  ('WJFINSL', 2, 0.0004381161007667032),
#  ('JCHZXJ', 2, 0.0004381161007667032),
#  ('HQTXJW', 2, 0.0004381161007667032),
#  ('RJRTWNJX', 2, 0.0004381161007667032),
#  ('BNXM', 2, 0.0004381161007667032),
#  ('ITTWX', 2, 0.0004381161007667032),
#  ('TBS', 2, 0.0004381161007667032),
#  ('ITHYTW', 2, 0.0004381161007667032),
#  ('WJFQ', 2, 0.0004381161007667032),
#  ('UFWJSYX', 2, 0.0004381161007667032),
#  ('KZYZWJ', 2, 0.0004381161007667032),
#  ('QFPJ', 2, 0.0004381161007667032),
#  ('XNW', 2, 0.0004381161007667032),
#  ('UQJFXZWJ', 2, 0.0004381161007667032),
#  ('UNQJX', 2, 0.0004381161007667032),
#  ('HNYD', 2, 0.0004381161007667032),
#  ('YJWWFHJ', 2, 0.0004381161007667032),
#  ('LWTZU', 2, 0.0004381161007667032),
#  ('RFWQJSJ', 2, 0.0004381161007667032),
#  ('YFGQJ', 2, 0.0004381161007667032),
#  ('YWZYM', 1, 0.0002190580503833516),
#  ('HMZWHM', 1, 0.0002190580503833516),
#  ('UTXJ', 1, 0.0002190580503833516),
#  ('UMTYTX', 1, 0.0002190580503833516),
#  ('FSDBFDX', 1, 0.0002190580503833516),
#  ('UTRU', 1, 0.0002190580503833516),
#  ('JQJHYWNH', 1, 0.0002190580503833516),
#  ('MTSJDRTTS', 1, 0.0002190580503833516),
#  ('RZXJX', 1, 0.0002190580503833516),
#  ('HDSNHFQQD', 1, 0.0002190580503833516),
#  ('HMFRGJWRFNI', 1, 0.0002190580503833516),
#  ('FUUWTFHM', 1, 0.0002190580503833516),
#  ('GTZLMY', 1, 0.0002190580503833516),
#  ('YMWJB', 1, 0.0002190580503833516),
#  ('YMTXJ', 1, 0.0002190580503833516),
#  ('BFSIJW', 1, 0.0002190580503833516),
#  ('FXPJI', 1, 0.0002190580503833516),
#  ('XQNIJX', 1, 0.0002190580503833516),
#  ('IWNAJW', 1, 0.0002190580503833516),
#  ('UQJFXJ', 1, 0.0002190580503833516),
#  ('XYJWS', 1, 0.0002190580503833516),
#  ('BMNXUJW', 1, 0.0002190580503833516),
#  ('XZUUTXJI', 1, 0.0002190580503833516),
#  ('IWTU', 1, 0.0002190580503833516),
#  ('ZSXZWJ', 1, 0.0002190580503833516),
#  ('KJJQNSL', 1, 0.0002190580503833516),
#  ('GWNSL', 1, 0.0002190580503833516),
#  ('HTZXNS', 1, 0.0002190580503833516),
#  ('MFWIQD', 1, 0.0002190580503833516),
#  ('KQTFYX', 1, 0.0002190580503833516),
#  ('HTTQ', 1, 0.0002190580503833516),
#  ('FWWTB', 1, 0.0002190580503833516),
#  ('RFSXNTS', 1, 0.0002190580503833516),
#  ('WJYZWSJI', 1, 0.0002190580503833516),
#  ('QNY', 1, 0.0002190580503833516),
#  ('XTZSI', 1, 0.0002190580503833516),
#  ('NQQZRNSFYJI', 1, 0.0002190580503833516),
#  ('YWJJX', 1, 0.0002190580503833516),
#  ('KFNW', 1, 0.0002190580503833516),
#  ('FSCNTZX', 1, 0.0002190580503833516),
#  ('XTRJ', 1, 0.0002190580503833516),
#  ('WTTRX', 1, 0.0002190580503833516),
#  ('YTSNLMY', 1, 0.0002190580503833516),
#  ('XBNRRNSL', 1, 0.0002190580503833516),
#  ('UTTQ', 1, 0.0002190580503833516),
#  ('RFIJ', 1, 0.0002190580503833516),
#  ('RNXJWD', 1, 0.0002190580503833516),
#  ('WFLLJI', 1, 0.0002190580503833516),
#  ('JSIX', 1, 0.0002190580503833516),
#  ('RFSNHZWJI', 1, 0.0002190580503833516),
#  ('UFWITS', 1, 0.0002190580503833516),
#  ('HFWWD', 1, 0.0002190580503833516),
#  ('XJQQNSL', 1, 0.0002190580503833516),
#  ('GTSIX', 1, 0.0002190580503833516),
#  ('FWJS', 1, 0.0002190580503833516),
#  ('NSYJWJXY', 1, 0.0002190580503833516),
#  ('HTSKNIJSYNFQ', 1, 0.0002190580503833516),
#  ('UNHP', 1, 0.0002190580503833516),
#  ('GNY', 1, 0.0002190580503833516),
#  ('BTQKXMJNR', 1, 0.0002190580503833516),
#  ('FXXZWJ', 1, 0.0002190580503833516),
#  ('XNSHJWNYD', 1, 0.0002190580503833516),
#  ('INXFWRX', 1, 0.0002190580503833516),
#  ('XYWTQQX', 1, 0.0002190580503833516),
#  ('GQFENSL', 1, 0.0002190580503833516),
#  ('XMTY', 1, 0.0002190580503833516),
#  ('JSTWRTZX', 1, 0.0002190580503833516),
#  ('HFWANSL', 1, 0.0002190580503833516),
#  ('GWTFI', 1, 0.0002190580503833516),
#  ('FWRD', 1, 0.0002190580503833516),
#  ('LNANSL', 1, 0.0002190580503833516),
#  ('UFNSY', 1, 0.0002190580503833516),
#  ('YWNRRJI', 1, 0.0002190580503833516),
#  ('MJFAD', 1, 0.0002190580503833516),
#  ('BMNYJ', 1, 0.0002190580503833516),
#  ('ITEJS', 1, 0.0002190580503833516),
#  ('HWDXYFQ', 1, 0.0002190580503833516),
#  ('TUJSNSL', 1, 0.0002190580503833516),
#  ('FWWNAJX', 1, 0.0002190580503833516),
#  ('HTSYNSZJ', 1, 0.0002190580503833516),
#  ('NSXNIJ', 1, 0.0002190580503833516),
#  ('INXYWFHYJIQD', 1, 0.0002190580503833516),
#  ('FBPBFWI', 1, 0.0002190580503833516),
#  ('HTRUWJMJSINSL', 1, 0.0002190580503833516),
#  ('BNIJW', 1, 0.0002190580503833516),
#  ('FGXZWIQD', 1, 0.0002190580503833516),
#  ('NSYJSXJQD', 1, 0.0002190580503833516),
#  ('UFHJX', 1, 0.0002190580503833516),
#  ('OTG', 1, 0.0002190580503833516),
#  ('BTS', 1, 0.0002190580503833516),
#  ('XYWFNLMYJSX', 1, 0.0002190580503833516),
#  ('MZWWNJIQD', 1, 0.0002190580503833516),
#  ('HMJHPX', 1, 0.0002190580503833516),
#  ('KJJY', 1, 0.0002190580503833516),
#  ('QJFANSL', 1, 0.0002190580503833516),
#  ('XNQQD', 1, 0.0002190580503833516),
#  ('RNSZYJX', 1, 0.0002190580503833516),
#  ('HTRNSL', 1, 0.0002190580503833516),
#  ('WTDHJ', 1, 0.0002190580503833516),
#  ('RZIID', 1, 0.0002190580503833516),
#  ('IJFWJXY', 1, 0.0002190580503833516),
#  ('RDXYJWNTZX', 1, 0.0002190580503833516),
#  ('XJHWJY', 1, 0.0002190580503833516),
#  ('UQFDNSL', 1, 0.0002190580503833516),
#  ('FQTSL', 1, 0.0002190580503833516),
#  ('HTSYNSZJX', 1, 0.0002190580503833516),
#  ('QNXYJSX', 1, 0.0002190580503833516),
#  ('MTUJKZQQD', 1, 0.0002190580503833516),
#  ('WJFHYNTS', 1, 0.0002190580503833516),
#  ('INXHTAJWNSL', 1, 0.0002190580503833516),
#  ('MJFWX', 1, 0.0002190580503833516),
#  ('KQTBJW', 1, 0.0002190580503833516),
#  ('INXUQFD', 1, 0.0002190580503833516),
#  ('LQFWJX', 1, 0.0002190580503833516),
#  ('ITNSL', 1, 0.0002190580503833516),
#  ('BTWI', 1, 0.0002190580503833516),
#  ('XJJX', 1, 0.0002190580503833516),
#  ('XZWWJFQ', 1, 0.0002190580503833516),
#  ('IWTBSNSL', 1, 0.0002190580503833516),
#  ('JRTYNTS', 1, 0.0002190580503833516),
#  ('SJHP', 1, 0.0002190580503833516),
#  ('XUFXR', 1, 0.0002190580503833516),
#  ('MTUJQJXX', 1, 0.0002190580503833516),
#  ('BTWIX', 1, 0.0002190580503833516),
#  ('UTZSI', 1, 0.0002190580503833516),
#  ('JJJJPPP', 1, 0.0002190580503833516),
#  ('GTNQNSL', 1, 0.0002190580503833516),
#  ('PJYYQJ', 1, 0.0002190580503833516),
#  ('XHWJJS', 1, 0.0002190580503833516),
#  ('WJXYX', 1, 0.0002190580503833516),
#  ('TUUTXNYJ', 1, 0.0002190580503833516),
#  ('KWTEJS', 1, 0.0002190580503833516),
#  ('HMFNW', 1, 0.0002190580503833516),
#  ('WFYYQJ', 1, 0.0002190580503833516),
#  ('YWFD', 1, 0.0002190580503833516),
#  ('HTSYWNGZYJX', 1, 0.0002190580503833516),
#  ('FQWJFID', 1, 0.0002190580503833516),
#  ('XTWWD', 1, 0.0002190580503833516),
#  ('HQZRXNQD', 1, 0.0002190580503833516),
#  ('IWTUX', 1, 0.0002190580503833516),
#  ('IJXUJWFYJ', 1, 0.0002190580503833516),
#  ('XJY', 1, 0.0002190580503833516),
#  ('RFSD', 1, 0.0002190580503833516),
#  ('FZYTRFYNH', 1, 0.0002190580503833516),
#  ('WJKQJC', 1, 0.0002190580503833516),
#  ('SJCY', 1, 0.0002190580503833516),
#  ('FSXBJW', 1, 0.0002190580503833516),
#  ('IDNSL', 1, 0.0002190580503833516),
#  ('RTWYNKNJI', 1, 0.0002190580503833516),
#  ('IFWQNSL', 1, 0.0002190580503833516),
#  ('UTZWX', 1, 0.0002190580503833516),
#  ('XYNKKQD', 1, 0.0002190580503833516),
#  ('MTWWNKNJI', 1, 0.0002190580503833516),
#  ('KTQQTBX', 1, 0.0002190580503833516),
#  ('FHYNSL', 1, 0.0002190580503833516),
#  ('WZIJ', 1, 0.0002190580503833516),
#  ('WFNXJX', 1, 0.0002190580503833516),
#  ('WJUWTFHMKZQQD', 1, 0.0002190580503833516),
#  ('LZFWINSL', 1, 0.0002190580503833516),
#  ('GJIWFLLQJI', 1, 0.0002190580503833516),
#  ('FYYJSYNTS', 1, 0.0002190580503833516),
#  ('YMWTFY', 1, 0.0002190580503833516),
#  ('XYTUUJI', 1, 0.0002190580503833516),
#  ('WFNSNSL', 1, 0.0002190580503833516),
#  ('WFINFSY', 1, 0.0002190580503833516),
#  ('AJXYNLJ', 1, 0.0002190580503833516),
#  ('QNYJWFQQD', 1, 0.0002190580503833516),
#  ('LQTBX', 1, 0.0002190580503833516),
#  ('BFQPX', 1, 0.0002190580503833516),
#  ('XYJU', 1, 0.0002190580503833516),
#  ('NAD', 1, 0.0002190580503833516),
#  ('HTAJWJI', 1, 0.0002190580503833516),
#  ('GWTZLMY', 1, 0.0002190580503833516),
#  ('STWRFSID', 1, 0.0002190580503833516),
#  ('LQNXYJSNSL', 1, 0.0002190580503833516),
#  ('XZSQNLMY', 1, 0.0002190580503833516),
#  ('HWD', 1, 0.0002190580503833516),
#  ('PJJU', 1, 0.0002190580503833516),
#  ('NSYJWJXYNSL', 1, 0.0002190580503833516),
#  ('RZWRZWX', 1, 0.0002190580503833516),
#  ('BMTQJ', 1, 0.0002190580503833516),
#  ('DJQQX', 1, 0.0002190580503833516),
#  ('IFZXD', 1, 0.0002190580503833516),
#  ('WTDFQ', 1, 0.0002190580503833516),
#  ('MZWWDNSL', 1, 0.0002190580503833516),
#  ('RFEJ', 1, 0.0002190580503833516),
#  ('KTZSYFNSX', 1, 0.0002190580503833516),
#  ('GWFSI', 1, 0.0002190580503833516),
#  ('OZNHJW', 1, 0.0002190580503833516),
#  ('RTIJWS', 1, 0.0002190580503833516),
#  ('WJFINJX', 1, 0.0002190580503833516),
#  ('XMFPJW', 1, 0.0002190580503833516),
#  ('GZYYTS', 1, 0.0002190580503833516),
#  ('XUQFXMJX', 1, 0.0002190580503833516),
#  ('UTSYTTS', 1, 0.0002190580503833516),
#  ('IWZSPJSQD', 1, 0.0002190580503833516),
#  ('GFQQX', 1, 0.0002190580503833516),
#  ('HFRHTWIJW', 1, 0.0002190580503833516),
#  ('WJRFWPFGQJ', 1, 0.0002190580503833516),
#  ('QFYJXY', 1, 0.0002190580503833516),
#  ('HZYX', 1, 0.0002190580503833516),
#  ('RFWAJQTZX', 1, 0.0002190580503833516),
#  ('HTAJW', 1, 0.0002190580503833516),
#  ('ATLZJ', 1, 0.0002190580503833516),
#  ('YWFNQ', 1, 0.0002190580503833516),
#  ('GJMNSI', 1, 0.0002190580503833516),
#  ('HWTXXNSL', 1, 0.0002190580503833516),
#  ('BZWQNYEJW', 1, 0.0002190580503833516),
#  ('KTTYRJS', 1, 0.0002190580503833516),
#  ('YBNWQX', 1, 0.0002190580503833516),
#  ('IJRFSI', 1, 0.0002190580503833516),
#  ('LFEJX', 1, 0.0002190580503833516),
#  ('XUQJSINI', 1, 0.0002190580503833516),
#  ('XYFNW', 1, 0.0002190580503833516),
#  ('YMWTBX', 1, 0.0002190580503833516),
#  ('WJAJFQNSL', 1, 0.0002190580503833516),
#  ('LTBSX', 1, 0.0002190580503833516),
#  ('YNJX', 1, 0.0002190580503833516),
#  ('HQTYMJX', 1, 0.0002190580503833516),
#  ('UQFDKZQQD', 1, 0.0002190580503833516),
#  ('GTFYJW', 1, 0.0002190580503833516),
#  ('YTXXNSL', 1, 0.0002190580503833516),
#  ('XJQJHYNTS', 1, 0.0002190580503833516),
#  ('GJLNSSNSL', 1, 0.0002190580503833516),
#  ('NSHWJFXNSL', 1, 0.0002190580503833516),
#  ('NSINFS', 1, 0.0002190580503833516),
#  ('JLDUYNFS', 1, 0.0002190580503833516),
#  ('HTYYTS', 1, 0.0002190580503833516),
#  ('NSYTCNHFYJI', 1, 0.0002190580503833516),
#  ('SNHPD', 1, 0.0002190580503833516),
#  ('YMZSIJW', 1, 0.0002190580503833516),
#  ('XQTBX', 1, 0.0002190580503833516),
#  ('KQZYYJW', 1, 0.0002190580503833516),
#  ('YWFSXKTWRX', 1, 0.0002190580503833516),
#  ('JFXJX', 1, 0.0002190580503833516),
#  ('GJXNIJ', 1, 0.0002190580503833516),
#  ('YJFW', 1, 0.0002190580503833516),
#  ('XYWJFPJI', 1, 0.0002190580503833516),
#  ('INWJHYNTS', 1, 0.0002190580503833516),
#  ('NSHFUFGQJ', 1, 0.0002190580503833516),
#  ('XUJFPNSL', 1, 0.0002190580503833516),
#  ('MJFWY', 1, 0.0002190580503833516),
#  ('QTXY', 1, 0.0002190580503833516),
#  ('RFSFLJ', 1, 0.0002190580503833516),
#  ('GZWSX', 1, 0.0002190580503833516),
#  ('XYFWJ', 1, 0.0002190580503833516),
#  ('HTQTXXFQ', 1, 0.0002190580503833516),
#  ('AFSNXMJI', 1, 0.0002190580503833516),
#  ('KTWJAJW', 1, 0.0002190580503833516),
#  ('HTZSY', 1, 0.0002190580503833516),
#  ('JSHMFSYJI', 1, 0.0002190580503833516),
#  ('TGOJHYX', 1, 0.0002190580503833516),
#  ('WJRNSI', 1, 0.0002190580503833516),
#  ('JRJWLJX', 1, 0.0002190580503833516),
#  ('XMFITBX', 1, 0.0002190580503833516),
#  ('IJXHJSIX', 1, 0.0002190580503833516),
#  ('JQIJWQD', 1, 0.0002190580503833516),
#  ('KFYMJW', 1, 0.0002190580503833516),
#  ('GJXY', 1, 0.0002190580503833516),
#  ('UQZHPX', 1, 0.0002190580503833516),
#  ('YTZHMJI', 1, 0.0002190580503833516),
#  ('QJYYJWX', 1, 0.0002190580503833516),
#  ('KQNUX', 1, 0.0002190580503833516),
#  ('MJWX', 1, 0.0002190580503833516),
#  ('LQTWNTZX', 1, 0.0002190580503833516),
#  ('YWZJ', 1, 0.0002190580503833516),
#  ('GGGWWWSSSLLL', 1, 0.0002190580503833516),
#  ('QTBJWX', 1, 0.0002190580503833516),
#  ('YNRGWJ', 1, 0.0002190580503833516),
#  ('IFWPJSX', 1, 0.0002190580503833516),
#  ('GTTTTRRR', 1, 0.0002190580503833516),
#  ('KWJSHM', 1, 0.0002190580503833516),
#  ('BNSITBX', 1, 0.0002190580503833516),
#  ('IJYWTNY', 1, 0.0002190580503833516),
#  ('NIJF', 1, 0.0002190580503833516),
#  ('WNSLX', 1, 0.0002190580503833516),
#  ('BMNHM', 1, 0.0002190580503833516),
#  ('GFSNXMJX', 1, 0.0002190580503833516),
#  ('JQJHYWNKDNSL', 1, 0.0002190580503833516),
#  ('OFZSYD', 1, 0.0002190580503833516),
#  ('UNUJ', 1, 0.0002190580503833516),
#  ('FBFPJ', 1, 0.0002190580503833516),
#  ('GJHTRNSL', 1, 0.0002190580503833516),
#  ('BJFWNSL', 1, 0.0002190580503833516),
#  ('KQTBNSL', 1, 0.0002190580503833516),
#  ('WTGJ', 1, 0.0002190580503833516),
#  ('MJJQX', 1, 0.0002190580503833516),
#  ('OTD', 1, 0.0002190580503833516),
#  ('NSYWTXUJHYNAJ', 1, 0.0002190580503833516),
#  ('KQTTI', 1, 0.0002190580503833516),
#  ('BWNYYJS', 1, 0.0002190580503833516),
#  ('LFYMJWNSL', 1, 0.0002190580503833516),
#  ('MZSIWJIX', 1, 0.0002190580503833516),
#  ('HFSIQJX', 1, 0.0002190580503833516),
#  ('KQNHPJW', 1, 0.0002190580503833516),
#  ('RJQFSHMTQNH', 1, 0.0002190580503833516),
#  ('BFQYE', 1, 0.0002190580503833516),
#  ('JCMFZXYJI', 1, 0.0002190580503833516),
#  ('QJFAJ', 1, 0.0002190580503833516),
#  ('JSTZLM', 1, 0.0002190580503833516),
#  ('ANXNTS', 1, 0.0002190580503833516),
#  ('ZSYNQ', 1, 0.0002190580503833516),
#  ('XNSHJ', 1, 0.0002190580503833516),
#  ('J', 1, 0.0002190580503833516),
#  ('XMWTZIJI', 1, 0.0002190580503833516),
#  ('IZXY', 1, 0.0002190580503833516),
#  ('BJWJ', 1, 0.0002190580503833516),
#  ('GFWJKTTY', 1, 0.0002190580503833516),
#  ('IZXYD', 1, 0.0002190580503833516),
#  ('XZWWTZSIJI', 1, 0.0002190580503833516),
#  ('YFYYJWJI', 1, 0.0002190580503833516),
#  ('GTTPX', 1, 0.0002190580503833516),
#  ('HMFWYX', 1, 0.0002190580503833516),
#  ('UWFHYNHNSL', 1, 0.0002190580503833516),
#  ('NRFLNSFYNTS', 1, 0.0002190580503833516),
#  ('LQTWD', 1, 0.0002190580503833516),
#  ('UWFNWNJ', 1, 0.0002190580503833516),
#  ('YJJSFLJ', 1, 0.0002190580503833516),
#  ('MNQQX', 1, 0.0002190580503833516),
#  ('HMFXNSL', 1, 0.0002190580503833516),
#  ('IJXYNSD', 1, 0.0002190580503833516),
#  ('WFS', 1, 0.0002190580503833516),
#  ('MFSIXTRJ', 1, 0.0002190580503833516),
#  ('HFSAFX', 1, 0.0002190580503833516),
#  ('UFSYX', 1, 0.0002190580503833516),
#  ('XUTYYJI', 1, 0.0002190580503833516),
#  ('UJWNQ', 1, 0.0002190580503833516),
#  ('BMNUUNSL', 1, 0.0002190580503833516),
#  ('AJXXJQ', 1, 0.0002190580503833516),
#  ('FQHTMTQNH', 1, 0.0002190580503833516),
#  ('RNQQNTSFNWJ', 1, 0.0002190580503833516),
#  ('BMFIEFRFYYF', 1, 0.0002190580503833516),
#  ('XMTFQ', 1, 0.0002190580503833516),
#  ('IWFL', 1, 0.0002190580503833516),
#  ('BFAJX', 1, 0.0002190580503833516),
#  ('BMFIJWFYMNSPDJWITNS', 1, 0.0002190580503833516),
#  ('HTQQFUXJX', 1, 0.0002190580503833516),
#  ('TUUTWYZSNYD', 1, 0.0002190580503833516),
#  ('XUWNSLNSL', 1, 0.0002190580503833516),
#  ('IJHNIJI', 1, 0.0002190580503833516),
#  ('RDXJQK', 1, 0.0002190580503833516),
#  ('MTNXYX', 1, 0.0002190580503833516),
#  ('UJWKJHY', 1, 0.0002190580503833516),
#  ('XFNQNSL', 1, 0.0002190580503833516),
#  ('XPNQQ', 1, 0.0002190580503833516),
#  ('YFZLMY', 1, 0.0002190580503833516),
#  ('HQTYMNSL', 1, 0.0002190580503833516),
#  ('XYTWJ', 1, 0.0002190580503833516),
#  ('XVZFWJQD', 1, 0.0002190580503833516),
#  ('WJUJFYX', 1, 0.0002190580503833516),
#  ('GTB', 1, 0.0002190580503833516),
#  ('HQJFW', 1, 0.0002190580503833516),
#  ('XFNQX', 1, 0.0002190580503833516),
#  ('XZS', 1, 0.0002190580503833516),
#  ('NSMJWNY', 1, 0.0002190580503833516),
#  ('KTWYZSJ', 1, 0.0002190580503833516),
#  ('INJI', 1, 0.0002190580503833516),
#  ('NSMJWNYFSHJ', 1, 0.0002190580503833516),
#  ('KFRNQD', 1, 0.0002190580503833516),
#  ('FGNQNYD', 1, 0.0002190580503833516),
#  ('XQFR', 1, 0.0002190580503833516),
#  ('SJBXUFUJWX', 1, 0.0002190580503833516),
#  ('XBNWQ', 1, 0.0002190580503833516),
#  ('WFUNIQD', 1, 0.0002190580503833516),
#  ('XYFLLJWNSL', 1, 0.0002190580503833516),
#  ('SJBX', 1, 0.0002190580503833516),
#  ('GZDNSL', 1, 0.0002190580503833516),
#  ('TZW', 1, 0.0002190580503833516),
#  ('NSAJXYRJSY', 1, 0.0002190580503833516),
#  ('XYWNPJX', 1, 0.0002190580503833516),
#  ('XYWJJY', 1, 0.0002190580503833516),
#  ('XPDXHWFUJWX', 1, 0.0002190580503833516),
#  ('UFDX', 1, 0.0002190580503833516),
#  ('UFWPX', 1, 0.0002190580503833516),
#  ('XYWJJYX', 1, 0.0002190580503833516),
#  ('PNSL', 1, 0.0002190580503833516),
#  ('KNSFQ', 1, 0.0002190580503833516),
#  ('HTAJWX', 1, 0.0002190580503833516),
#  ('RDXYJWD', 1, 0.0002190580503833516),
#  ('RNQQNTSX', 1, 0.0002190580503833516),
#  ('WZRTWX', 1, 0.0002190580503833516),
#  ('UFUJW', 1, 0.0002190580503833516),
#  ('HTRJX', 1, 0.0002190580503833516),
#  ('LWTYJXVZJ', 1, 0.0002190580503833516),
#  ('IWZSPJS', 1, 0.0002190580503833516),
#  ('WJAJQQJWX', 1, 0.0002190580503833516),
#  ('BFSYJI', 1, 0.0002190580503833516),
#  ('FHHTRUFSNJI', 1, 0.0002190580503833516),
#  ('LWJFY', 1, 0.0002190580503833516),
#  ('GWNJKQD', 1, 0.0002190580503833516),
#  ('RZYYJWX', 1, 0.0002190580503833516),
#  ('WNHM', 1, 0.0002190580503833516),
#  ('GTTYQJLLJWX', 1, 0.0002190580503833516),
#  ('TBSJI', 1, 0.0002190580503833516),
#  ('LWFHJKZQQD', 1, 0.0002190580503833516),
#  ('RWX', 1, 0.0002190580503833516),
#  ('MJXNYFYNTS', 1, 0.0002190580503833516),
#  ('TGOJHYNSL', 1, 0.0002190580503833516),
#  ('VZNHPQD', 1, 0.0002190580503833516),
#  ('XMFPNSL', 1, 0.0002190580503833516),
#  ('STIX', 1, 0.0002190580503833516),
#  ('GNIX', 1, 0.0002190580503833516),
#  ('LQTBJWX', 1, 0.0002190580503833516),
#  ('UWTZI', 1, 0.0002190580503833516),
#  ('NSYJWOJHYX', 1, 0.0002190580503833516),
#  ('LZNIJX', 1, 0.0002190580503833516),
#  ('KFHJX', 1, 0.0002190580503833516),
#  ('XHTKKX', 1, 0.0002190580503833516),
#  ('WJHTLSNEJ', 1, 0.0002190580503833516),
#  ('TWHMNI', 1, 0.0002190580503833516),
#  ('FITWJ', 1, 0.0002190580503833516),
#  ('WJUJFYNSL', 1, 0.0002190580503833516),
#  ('JQFGTWFYJQD', 1, 0.0002190580503833516),
#  ('HTSHJNAJI', 1, 0.0002190580503833516),
#  ('JCHNYJ', 1, 0.0002190580503833516),
#  ('RTSYM', 1, 0.0002190580503833516),
#  ('KFDJ', 1, 0.0002190580503833516),
#  ('HNWHZRXYFSHJ', 1, 0.0002190580503833516),
#  ('YMFS', 1, 0.0002190580503833516),
#  ('XYWTQQ', 1, 0.0002190580503833516),
#  ('XNLSX', 1, 0.0002190580503833516),
#  ('YTZHMNSL', 1, 0.0002190580503833516),
#  ('FHYZFQQD', 1, 0.0002190580503833516),
#  ('MZXGFSI', 1, 0.0002190580503833516),
#  ('BJJP', 1, 0.0002190580503833516),
#  ('HWFXMJI', 1, 0.0002190580503833516),
#  ('MTYJQ', 1, 0.0002190580503833516),
#  ('HZWG', 1, 0.0002190580503833516),
#  ('XYWZHP', 1, 0.0002190580503833516),
#  ('UZEEQJI', 1, 0.0002190580503833516),
#  ('NXS', 1, 0.0002190580503833516),
#  ('GJNSL', 1, 0.0002190580503833516),
#  ('BMNWQX', 1, 0.0002190580503833516),
#  ('HTSXYFSYQD', 1, 0.0002190580503833516),
#  ('BFSYX', 1, 0.0002190580503833516),
#  ('RTIJXYD', 1, 0.0002190580503833516),
#  ('PNSI', 1, 0.0002190580503833516),
#  ('XBJJYMJFWYX', 1, 0.0002190580503833516),
#  ('RJFS', 1, 0.0002190580503833516),
#  ('MFUUJS', 1, 0.0002190580503833516),
#  ('WJRJRGJW', 1, 0.0002190580503833516),
#  ('BTSIJWX', 1, 0.0002190580503833516),
#  ('ZSIJW', 1, 0.0002190580503833516),
#  ('YWFHP', 1, 0.0002190580503833516),
#  ('FGQFEJ', 1, 0.0002190580503833516),
#  ('YTBJW', 1, 0.0002190580503833516),
#  ('HJQQFW', 1, 0.0002190580503833516),
#  ('XYWNINSL', 1, 0.0002190580503833516),
#  ('YJWWNGQD', 1, 0.0002190580503833516),
#  ('LQFSHNSL', 1, 0.0002190580503833516),
#  ('UQZSLJ', 1, 0.0002190580503833516),
#  ('HWJXYKFQQJS', 1, 0.0002190580503833516),
#  ('UZYX', 1, 0.0002190580503833516),
#  ('LTNSL', 1, 0.0002190580503833516),
#  ('XNIJ', 1, 0.0002190580503833516),
#  ('XNIJQNSJ', 1, 0.0002190580503833516),
#  ('XFDNSL', 1, 0.0002190580503833516),
#  ('YWDNSL', 1, 0.0002190580503833516),
#  ('MFUUJSX', 1, 0.0002190580503833516),
#  ('SNHJ', 1, 0.0002190580503833516),
#  ('STI', 1, 0.0002190580503833516),
#  ('LFEJ', 1, 0.0002190580503833516),
#  ('ZUTS', 1, 0.0002190580503833516),
#  ('RTBJW', 1, 0.0002190580503833516),
#  ('HQFYYJWX', 1, 0.0002190580503833516),
#  ('LFWISIJWX', 1, 0.0002190580503833516),
#  ('MJILJX', 1, 0.0002190580503833516),
#  ('IWJXXJI', 1, 0.0002190580503833516),
#  ('YNJ', 1, 0.0002190580503833516),
#  ('MTQINSL', 1, 0.0002190580503833516),
#  ('MJWETL', 1, 0.0002190580503833516),
#  ('XMJQYJW', 1, 0.0002190580503833516),
#  ('AFXJX', 1, 0.0002190580503833516),
#  ('UFWFIJ', 1, 0.0002190580503833516),
#  ('XYTU', 1, 0.0002190580503833516),
#  ('OTZWSFQ', 1, 0.0002190580503833516),
#  ('YNLMY', 1, 0.0002190580503833516),
#  ('YNHPNSL', 1, 0.0002190580503833516),
#  ('HWTBIJI', 1, 0.0002190580503833516),
#  ('NRUWJXXJI', 1, 0.0002190580503833516),
#  ('FR', 1, 0.0002190580503833516),
#  ('BFNY', 1, 0.0002190580503833516),
#  ('STGTID', 1, 0.0002190580503833516),
#  ('GJJJJJU', 1, 0.0002190580503833516),
#  ('FWWNANSL', 1, 0.0002190580503833516),
#  ('UFSNH', 1, 0.0002190580503833516),
#  ('WFHNSL', 1, 0.0002190580503833516),
#  ('IWNAJS', 1, 0.0002190580503833516),
#  ('FXXNXYX', 1, 0.0002190580503833516),
#  ('LWFAJ', 1, 0.0002190580503833516),
#  ('MFSLX', 1, 0.0002190580503833516),
#  ('LTTISJXX', 1, 0.0002190580503833516),
#  ('WFSXFHP', 1, 0.0002190580503833516),
#  ('LWJJSMTZXJ', 1, 0.0002190580503833516),
#  ('MJWXJQK', 1, 0.0002190580503833516),
#  ('XMTHPJI', 1, 0.0002190580503833516),
#  ('RJWJQD', 1, 0.0002190580503833516),
#  ('FIRNWNSL', 1, 0.0002190580503833516),
#  ('UFQJ', 1, 0.0002190580503833516),
#  ('IJFYM', 1, 0.0002190580503833516),
#  ('XYFQPX', 1, 0.0002190580503833516),
#  ('RFWAJQQNSL', 1, 0.0002190580503833516),
#  ('NSYFPJ', 1, 0.0002190580503833516),
#  ...]

# %% [markdown]
# ---

# %% [markdown]
# ### Frequency of the characters in the document

# %%
chars3freq = chars3\
    .map(lambda x: (x.lower(), 1))\
        .reduceByKey(lambda num_char1, num_char2: num_char1+num_char2)\
            .map(lambda x: (x[0], x[1], x[1]/float(num3chars)))\
                .filter(lambda x: x[0] != ' ')\
                    .sortBy(lambda x: x[1], ascending=False)

# %%
chars3freq.collect()
# Out:
# [('j', 1817, 0.07621964008557405),
#  ('f', 1732, 0.07265405428080036),
#  ('y', 1726, 0.07240236587105164),
#  ('x', 1628, 0.06829145517848903),
#  ('t', 1482, 0.06216703720793657),
#  ('n', 1366, 0.057301061286127775),
#  ('s', 1358, 0.056965476739796135),
#  ('w', 989, 0.04148663954024917),
#  ('m', 863, 0.03620118293552582),
#  ('q', 818, 0.03431351986241034),
#  ('i', 793, 0.03326481815512396),
#  ('d', 702, 0.029447543940601534),
#  ('l', 612, 0.02567221779437057),
#  ('h', 604, 0.025336633248038927),
#  ('z', 504, 0.02114182641889341),
#  ('g', 446, 0.01870883845798901),
#  ('r', 406, 0.0170309157263308),
#  ('b', 340, 0.01426234321909476),
#  ('p', 324, 0.013591174126431477),
#  ('k', 296, 0.012416628214270732),
#  ('u', 282, 0.011829355258190361),
#  ('a', 201, 0.008431561726582491),
#  ('o', 58, 0.0024329879609044005),
#  ('c', 39, 0.001635974663366752),
#  ('e', 20, 0.0008389613658291036),
#  ('v', 7, 0.00029363647804018627)]

# %% [markdown]
# ---

# %% [markdown]
# ### Find the encryption key by using the most frequently occuring letter

# %% [markdown]
# #### Combined letter frequencies from the document with the relative frequencies of the English language (comparison purposes only)

# %%
char_freqs = chars3freq\
    .sortBy(lambda x: x[0])\
        .map(lambda x: f'{round(x[2]*100, 3)}%')

# %%
char_freqs.collect()
# Out:
# ['0.843%',
#  '1.426%',
#  '0.164%',
#  '2.945%',
#  '0.084%',
#  '7.265%',
#  '1.871%',
#  '2.534%',
#  '3.326%',
#  '7.622%',
#  '1.242%',
#  '2.567%',
#  '3.62%',
#  '5.73%',
#  '0.243%',
#  '1.359%',
#  '3.431%',
#  '1.703%',
#  '5.697%',
#  '6.217%',
#  '1.183%',
#  '0.029%',
#  '4.149%',
#  '6.829%',
#  '7.24%',
#  '2.114%']

# %%
import pandas as pd

freq_df = pd.read_html(
    'https://en.wikipedia.org/wiki/Letter_frequency'
)[0]

freq_df.drop(
    ['Relative frequency in the English language.1'], 
    axis=1, 
    inplace=True
)

freq_df['observed frequency'] = char_freqs.collect()

freq_df.index = freq_df.Letter

freq_df.drop(
    ['Letter'], 
    axis=1, 
    inplace=True
)

freq_df.columns = ['Relative', 'Observed']

freq_df['R'] = freq_df.Relative.map(lambda x: float(x[:-1]))
freq_df['O'] = freq_df.Observed.map(lambda x: float(x[:-1]))
freq_df['difference'] = freq_df['R'] - freq_df['O']
freq_df.difference = freq_df.difference.map(lambda x: f'{round(x, 3)}%')
freq_df.drop(
    ['R', 'O'], 
    axis=1, 
    inplace=True
)

freq_df
# Out:
#        Relative Observed difference
# Letter
# a        8.167%   0.843%     7.324%
# b        1.492%   1.426%     0.066%
# c        2.202%   0.164%     2.038%
# d        4.253%   2.945%     1.308%
# e       12.702%   0.084%    12.618%
# f        2.228%   7.265%    -5.037%
# g        2.015%   1.871%     0.144%
# h        6.094%   2.534%      3.56%
# i        6.966%   3.326%      3.64%
# j        0.153%   7.622%    -7.469%
# k        1.292%   1.242%      0.05%
# l        4.025%   2.567%     1.458%
# m        2.406%    3.62%    -1.214%
# n        6.749%    5.73%     1.019%
# o        7.507%   0.243%     7.264%
# p        1.929%   1.359%      0.57%
# q        0.095%   3.431%    -3.336%
# r        5.987%   1.703%     4.284%
# s        6.327%   5.697%      0.63%
# t        9.356%   6.217%     3.139%
# u        2.758%   1.183%     1.575%
# v        0.978%   0.029%     0.949%
# w        2.560%   4.149%    -1.589%
# x        0.150%   6.829%    -6.679%
# y        1.994%    7.24%    -5.246%
# z        0.077%   2.114%    -2.037%

# %% [markdown]
# ---

# %% [markdown]
# ### Assuming the most common encrypted letter decrypts to 'E'

# %%
most_freq_letter = chars3freq.map(lambda x: x[0].upper()).first()

# %%
def find_key(letter):
    return 26 + (ord('E') - ord(letter))

# %%
encryption_key = find_key(most_freq_letter)
encryption_key
# Out:
# 21

# %% [markdown]
# ---

# %% [markdown]
# ### Test the encryption key by using a random encrypted word and shifting its letters

# %%
import nltk.corpus as nc

def test_key(encrypted_word, key):
    new_word = ''
    
    for letter in encrypted_word:
        shifted_letter = ord(letter) + key
        
        if shifted_letter > 90:
            shifted_letter -= 26
        new_word += chr(shifted_letter)

    if new_word.lower() in nc.words.words():
        print(new_word)

# %%
random_word = words3.sample(withReplacement=True, fraction=0.0002)
random_word.first()
# Out:
# 'YMJD'

# %%
test_key(random_word.first(), encryption_key)
# Out:
# THEY

# %% [markdown]
# ##### it works!

# %% [markdown]
# ---

# %%
def decrypt(encrypted_element, key):
    new_element = ''
    for element in encrypted_element:
        shifted_element = ord(element) + key

        if shifted_element > 90:
            shifted_element -= 26
        new_element += chr(shifted_element)
        
    return new_element

# %%
def decrypt_file(file_name):
    letters = list('ABCDEFGHIJKLMNOPQRSTUVWXYZ')
    
    with open(file_name, 'r') as f:
        txt = f.read()
    
    decrypted_txt = ''

    for char in txt:
        if char in letters:
            char = decrypt(char, encryption_key)

        decrypted_txt += char

    return decrypted_txt

# %% [markdown]
# ###### for comparison purposes

# %%
# print(
#     open('Encrypted-3.txt', 'r').read()
# )

# %%
# print(
#     decrypt_file('Encrypted-3.txt')
# )

# %% [markdown]
# ###### final decryption

# %%
with open('Decrypted-3.txt', 'w') as f:
    f.write(
        decrypt_file('Encrypted-3.txt')
    )
